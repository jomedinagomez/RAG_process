# %% [markdown]
# ### Create a search index

# %%
from dotenv import load_dotenv
from azure.identity import DefaultAzureCredential
from azure.core.credentials import AzureKeyCredential
import os
import pandas as pd
from azure.search.documents import SearchClient  

load_dotenv(override=True) # take environment variables from .env.

# Variables not used here do not need to be updated in your .env file
AZURE_SEARCH_SERVICE_ENDPOINT = os.environ["AZURE_SEARCH_SERVICE_ENDPOINT"]
AZURE_SEARCH_ADMIN_CREDENTIAL = AzureKeyCredential(os.getenv("AZURE_SEARCH_ADMIN_KEY")) if os.getenv("AZURE_SEARCH_ADMIN_KEY") else DefaultAzureCredential()
index_name = os.environ["AZURE_SEARCH_INDEX_NAME"].lower().replace("_", "-")

azure_openai_endpoint = os.environ["AZURE_OPENAI_ENDPOINT"]
azure_openai_key = os.getenv("AZURE_OPENAI_API_KEY")
azure_openai_embedding_deployment = os.getenv("AZURE_OPENAI_EMBEDDING_DEPLOYMENT", "text-embedding-3-small")
azure_openai_model_name = os.getenv("AZURE_OPENAI_EMBEDDING_MODEL_NAME", "text-embedding-3-small")
azure_openai_model_dimensions = int(os.getenv("AZURE_OPENAI_EMBEDDING_DIMENSIONS", 1536))

# note: The chat deployment should support tool use
# To learn more, please see
# https://learn.microsoft.com/en-us/azure/ai-services/openai/concepts/models#gpt-4-and-gpt-4-turbo-models
# https://learn.microsoft.com/en-us/azure/ai-services/openai/concepts/models#gpt-35
azure_openai_chat_deployment = os.getenv("AZURE_OPENAI_CHATGPT_DEPLOYMENT", "gpt-4o-mini")
azure_openai_api_version = os.getenv("AZURE_OPENAI_API_VERSION", "2024-07-01-preview")

# %% [markdown]
# ### Read data

# %%
path = "../../data/processed/files/"
filelist = os.listdir(path)

# %%
load_df
# Out:
#       page_num                                            content  \
# 0            1  Table of Contents\nUNITED STATES SECURITIES AN...
# 1            2  Table of Contents\nAMAZON.COM, INC. FORM 10-K ...
# 2            3  Table of Contents\nAMAZON.COM, INC.\nPART I\nI...
# 3            4  Table of Contents\nCompetition\nOur businesses...
# 4            5  Table of Contents\nAvailable Information\nOur ...
# ...        ...                                                ...
# 1991        76  Exhibit 15.1\nOctober 25, 2022\nThe Board of D...
# 1992        77  Exhibit 31.1\nCERTIFICATION\nI, Satya Nadella,...
# 1993        78  Exhibit 31.2\nCERTIFICATION\nI, Amy E. Hood, c...
# 1994        79  Exhibit 32.1\nCERTIFICATION PURSUANT TO SECTIO...
# 1995        80  Exhibit 32.2\nCERTIFICATION PURSUANT TO SECTIO...
#
#                                                   title  \
# 0                                             FORM 10-K
# 1     AMAZON.COM, INC. FORM 10-K For the Fiscal Year...
# 2                                      Item 1. Business
# 3                                           Competition
# 4                      Executive Officers and Directors
# ...                                                 ...
# 1991                                       Exhibit 15.1
# 1992                       Exhibit 31.1 - Certification
# 1993                       Exhibit 31.2 - Certification
# 1994  CERTIFICATION PURSUANT TO SECTION 906 OF THE S...
# 1995  CERTIFICATION PURSUANT TO SECTION 906 OF THE S...
#
#                                            title_vector  \
# 0     [0.06034832075238228, 0.05649842694401741, 0.0...
# 1     [0.036177292466163635, 0.02635868266224861, 0....
# 2     [0.005116552114486694, 0.010721826925873756, 0...
# 3     [0.03811872377991676, -0.02396334894001484, 0....
# 4     [0.0003115860163234174, -0.014203808270394802,...
# ...                                                 ...
# 1991  [-0.014841333031654358, 0.03249764069914818, -...
# 1992  [-0.014201141893863678, 0.02938828431069851, 0...
# 1993  [-0.004663168452680111, 0.033500369638204575, ...
# 1994  [0.036175042390823364, 0.01837925612926483, -0...
# 1995  [0.03610779717564583, 0.018193941563367844, -0...
#
#                                          content_vector  \
# 0     [0.05381559208035469, 0.026631174609065056, 0....
# 1     [0.022779833525419235, 0.041926249861717224, 0...
# 2     [0.043223753571510315, 0.009905443526804447, 0...
# 3     [0.04903312399983406, 0.028485119342803955, 0....
# 4     [0.019433414563536644, -0.01925777457654476, 0...
# ...                                                 ...
# 1991  [0.04970259964466095, 0.011187892407178879, 0....
# 1992  [0.02333853580057621, 0.010006517171859741, 0....
# 1993  [0.022416625171899796, 0.00013361001037992537,...
# 1994  [0.04927904158830643, 0.027612054720520973, 0....
# 1995  [0.042830418795347214, 0.018417783081531525, 0...
#
#                              chunk_id     preprocessing_pipeline  \
# 0      10K-AMZN-02-03-2023-chunk-id-1  DI_Text_HTML_PageSplitter
# 1      10K-AMZN-02-03-2023-chunk-id-2  DI_Text_HTML_PageSplitter
# 2      10K-AMZN-02-03-2023-chunk-id-3  DI_Text_HTML_PageSplitter
# 3      10K-AMZN-02-03-2023-chunk-id-4  DI_Text_HTML_PageSplitter
# 4      10K-AMZN-02-03-2023-chunk-id-5  DI_Text_HTML_PageSplitter
# ...                               ...                        ...
# 1991  10Q-MSFT-10-25-2022-chunk-id-76  DI_Text_HTML_PageSplitter
# 1992  10Q-MSFT-10-25-2022-chunk-id-77  DI_Text_HTML_PageSplitter
# 1993  10Q-MSFT-10-25-2022-chunk-id-78  DI_Text_HTML_PageSplitter
# 1994  10Q-MSFT-10-25-2022-chunk-id-79  DI_Text_HTML_PageSplitter
# 1995  10Q-MSFT-10-25-2022-chunk-id-80  DI_Text_HTML_PageSplitter
#
#                  filename filing_period filing_date form_type ticker  \
# 0     10K-AMZN-02-03-2023    2022-12-31  2023-02-03       10K   AMZN
# 1     10K-AMZN-02-03-2023    2022-12-31  2023-02-03       10K   AMZN
# 2     10K-AMZN-02-03-2023    2022-12-31  2023-02-03       10K   AMZN
# 3     10K-AMZN-02-03-2023    2022-12-31  2023-02-03       10K   AMZN
# 4     10K-AMZN-02-03-2023    2022-12-31  2023-02-03       10K   AMZN
# ...                   ...           ...         ...       ...    ...
# 1991  10Q-MSFT-10-25-2022    2022-09-30  2022-10-25       10Q   MSFT
# 1992  10Q-MSFT-10-25-2022    2022-09-30  2022-10-25       10Q   MSFT
# 1993  10Q-MSFT-10-25-2022    2022-09-30  2022-10-25       10Q   MSFT
# 1994  10Q-MSFT-10-25-2022    2022-09-30  2022-10-25       10Q   MSFT
# 1995  10Q-MSFT-10-25-2022    2022-09-30  2022-10-25       10Q   MSFT
#
#                                    id
# 0      10K-AMZN-02-03-2023-chunk-id-1
# 1      10K-AMZN-02-03-2023-chunk-id-2
# 2      10K-AMZN-02-03-2023-chunk-id-3
# 3      10K-AMZN-02-03-2023-chunk-id-4
# 4      10K-AMZN-02-03-2023-chunk-id-5
# ...                               ...
# 1991  10Q-MSFT-10-25-2022-chunk-id-76
# 1992  10Q-MSFT-10-25-2022-chunk-id-77
# 1993  10Q-MSFT-10-25-2022-chunk-id-78
# 1994  10Q-MSFT-10-25-2022-chunk-id-79
# 1995  10Q-MSFT-10-25-2022-chunk-id-80
#
# [1996 rows x 13 columns]

# %%
load_df = pd.DataFrame()
for filename in filelist:
    df = pd.read_parquet(path + filename)
    load_df = pd.concat([load_df, df], ignore_index=True)

load_df = load_df.reset_index(drop=True)
load_df['title_vector'] = load_df['title_vector'].apply(lambda x: x.tolist())
load_df['content_vector'] = load_df['content_vector'].apply(lambda x: x.tolist())
load_df['id'] = load_df['chunk_id']
#load_df = load_df.drop(columns=['page_num','chunk_id','preprocessing_pipeline','filing_period','filing_date'])

# %%
input_data = load_df.to_dict(orient='records')

# Generate embeddings for title and content fields
for item in input_data:
    item['@search.action'] = 'upload'

# %%
search_client = SearchClient(endpoint=AZURE_SEARCH_SERVICE_ENDPOINT, index_name=index_name, credential=AZURE_SEARCH_ADMIN_CREDENTIAL)


for ai_search_document in input_data:
    search_client.upload_documents(ai_search_document)
