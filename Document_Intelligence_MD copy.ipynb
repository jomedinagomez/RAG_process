# %% [markdown]
# ### Part 0. Loading libraries

# %%
from azure.core.credentials import AzureKeyCredential
from azure.ai.documentintelligence import DocumentIntelligenceClient
from azure.ai.documentintelligence.models import AnalyzeDocumentRequest, ContentFormat
from azure.ai.documentintelligence.models import AnalyzeDocumentRequest, DocumentAnalysisFeature
from azure.ai.documentintelligence.models import DocumentTable

from langchain.text_splitter import MarkdownHeaderTextSplitter
import os
from dotenv import load_dotenv
import pandas as pd
import mdpd
import re

load_dotenv()

endpoint = os.environ["AZURE_DOC_INTELLIGENCE_ENDPOINT"]
key = os.environ["AZURE_DOC_INTELLIGENCE_KEY"]

document_intelligence_client = DocumentIntelligenceClient(endpoint=endpoint, credential=AzureKeyCredential(key), api_version="2024-02-29-preview")
# Out:
# c:\Users\jomedin\AppData\Local\anaconda3\Lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
path_to_sample_documents = os.path.abspath(
    os.path.join(
        "MICROSOFT-10Q-FY2023-Q3.pdf",
    )
)
filename = path_to_sample_documents
with open(filename, "rb") as f:
    poller = document_intelligence_client.begin_analyze_document("prebuilt-layout", 
                                                                 analyze_request=f, content_type="application/octet-stream", 
                                                                 output_content_format=ContentFormat.MARKDOWN,
                                                                 features=[DocumentAnalysisFeature.KEY_VALUE_PAIRS])
result = poller.result()

# %%
sections = []
for section in result.paragraphs:
    if section.role:
        print(section.role)
        print(section.bounding_regions[0].page_number)
        print(section.content)

result.paragraphs
# Out:
# title
# 1
# UNITED STATES SECURITIES AND EXCHANGE COMMISSION Washington, D.C. 20549
# ===
# sectionHeading
# 1
# ## MICROSOFT CORPORATION
# title
# 2
# MICROSOFT CORPORATION FORM 10-Q For the Quarter Ended March 31, 2023 INDEX
# ===
# pageNumber
# 2
# <!-- PageNumber="2" -->
# title
# 3
# PART ! Item 1
# ===
# title
# 3
# PART I. FINANCIAL INFORMATION ITEM 1. FINANCIAL STATEMENTS INCOME STATEMENTS
# ===
# pageNumber
# 3
# <!-- PageNumber="3" -->
# title
# 4
# COMPREHENSIVE INCOME STATEMENTS
# ===
# title
# 5
# PART I Item 1
# ===
# pageNumber
# 5
# <!-- PageNumber="5" -->
# title
# 5
# BALANCE SHEETS
# ===
# title
# 6
# PART ! Item 1
# ===
# title
# 6
# CASH FLOWS STATEMENTS
# ===
# pageNumber
# 6
# <!-- PageNumber="6" -->
# title
# 7
# PART ! Item 1
# ===
# title
# 7
# STOCKHOLDERS' EQUITY STATEMENTS
# ===
# pageNumber
# 7
# <!-- PageNumber="7" -->
# sectionHeading
# 8
# ## Accounting Principles
# sectionHeading
# 8
# ## Principles of Consolidation
# sectionHeading
# 8
# ### Estimates and Assumptions
# sectionHeading
# 8
# ## Financial Instruments
# sectionHeading
# 8
# ### Investments
# pageNumber
# 8
# <!-- PageNumber="8" -->
# pageHeader
# 9
# <!-- PageHeader="PART I Item 1" -->
# sectionHeading
# 9
# #### Derivatives
# sectionHeading
# 9
# ## Fair Value Measurements
# pageNumber
# 9
# <!-- PageNumber="9" -->
# pageHeader
# 10
# <!-- PageHeader="PART I Item 1" -->
# sectionHeading
# 10
# ### Contract Balances and Other Receivables
# sectionHeading
# 10
# ## Employee Severance
# pageNumber
# 10
# <!-- PageNumber="10" -->
# pageHeader
# 11
# <!-- PageHeader="PART I Item 1" -->
# sectionHeading
# 11
# ## NOTE 2 - EARNINGS PER SHARE
# sectionHeading
# 11
# ## Net Recognized Gains (Losses) on Investments
# pageNumber
# 11
# <!-- PageNumber="11" -->
# pageHeader
# 12
# <!-- PageHeader="PART I Item 1" -->
# title
# 13
# NOTE 4 - INVESTMENTS
# ===
# sectionHeading
# 13
# ## Investment Components
# pageNumber
# 13
# <!-- PageNumber="13" -->
# pageHeader
# 15
# <!-- PageHeader="PART I Item 1" -->
# sectionHeading
# 15
# ## Unrealized Losses on Debt Investments
# sectionHeading
# 15
# ## Debt Investment Maturities
# pageNumber
# 15
# <!-- PageNumber="15" -->
# title
# 16
# NOTE 5 - DERIVATIVES
# ===
# sectionHeading
# 16
# ## Foreign Currencies
# sectionHeading
# 16
# ## Interest Rate
# sectionHeading
# 16
# ## Equity
# sectionHeading
# 16
# ## Credit
# sectionHeading
# 16
# ## Credit-Risk-Related Contingent Features
# pageNumber
# 16
# <!-- PageNumber="16" -->
# pageHeader
# 17
# <!-- PageHeader="PART I Item 1" -->
# sectionHeading
# 17
# ### Fair Values of Derivative Instruments
# pageNumber
# 17
# <!-- PageNumber="17" -->
# pageNumber
# 18
# <!-- PageNumber="18" -->
# pageHeader
# 19
# <!-- PageHeader="PART ! Item 1" -->
# title
# 19
# NOTE 7 - BUSINESS COMBINATIONS
# ===
# sectionHeading
# 19
# ## Nuance Communications, Inc.
# sectionHeading
# 19
# ### Activision Blizzard, Inc.
# pageNumber
# 19
# <!-- PageNumber="19" -->
# pageHeader
# 20
# <!-- PageHeader="PART I Item 1" -->
# sectionHeading
# 20
# ## (In millions)
# pageNumber
# 20
# <!-- PageNumber="20" -->
# pageHeader
# 22
# <!-- PageHeader="PART I Item 1" -->
# sectionHeading
# 22
# ### NOTE 11 - INCOME TAXES
# sectionHeading
# 22
# ## Effective Tax Rate
# sectionHeading
# 22
# ## Uncertain Tax Positions
# pageNumber
# 22
# <!-- PageNumber="22" -->
# pageHeader
# 23
# <!-- PageHeader="PART ! Item 1" -->
# sectionHeading
# 23
# ### NOTE 13 - LEASES
# pageNumber
# 23
# <!-- PageNumber="23" -->
# sectionHeading
# 24
# ## (In millions)
# pageNumber
# 24
# <!-- PageNumber="24" -->
# pageHeader
# 25
# <!-- PageHeader="PART ! Item 1" -->
# sectionHeading
# 25
# ## NOTE 14 - CONTINGENCIES
# sectionHeading
# 25
# ## U.S. Cell Phone Litigation
# sectionHeading
# 25
# ## Other Contingencies
# sectionHeading
# 25
# ### Share Repurchases
# pageNumber
# 25
# <!-- PageNumber="25" -->
# title
# 26
# PART ! Item 1
# ===
# sectionHeading
# 26
# ## Dividends
# pageNumber
# 26
# <!-- PageNumber="26" -->
# title
# 27
# PART ! Item 1
# ===
# title
# 27
# NOTE 16 - ACCUMULATED OTHER COMPREHENSIVE INCOME (LOSS).
# ===
# pageNumber
# 27
# <!-- PageNumber="27" -->
# pageHeader
# 28
# <!-- PageHeader="PART ! Item 1" -->
# title
# 28
# NOTE 17 - SEGMENT INFORMATION AND GEOGRAPHIC DATA
# ===
# sectionHeading
# 28
# ## Productivity and Business Processes
# sectionHeading
# 28
# ## Intelligent Cloud
# sectionHeading
# 28
# ## More Personal Computing
# pageNumber
# 28
# <!-- PageNumber="28" -->
# pageHeader
# 29
# <!-- PageHeader="PART ! Item 1" -->
# pageNumber
# 29
# <!-- PageNumber="29" -->
# pageNumber
# 30
# <!-- PageNumber="30" -->
# title
# 31
# REPORT OF INDEPENDENT REGISTERED PUBLIC ACCOUNTING FIRM
# ===
# sectionHeading
# 31
# ## Results of Review of Interim Financial Information
# sectionHeading
# 31
# ### Basis for Review Results
# pageNumber
# 31
# <!-- PageNumber="31" -->
# title
# 32
# ITEM 2. MANAGEMENT'S DISCUSSION AND ANALYSIS OF FINANCIAL CONDITION AND RESULTS OF OPERATIONS
# ===
# sectionHeading
# 32
# ## Note About Forward-Looking Statements
# sectionHeading
# 32
# ## OVERVIEW
# pageNumber
# 32
# <!-- PageNumber="32" -->
# pageHeader
# 33
# <!-- PageHeader="PART ! Item 2" -->
# sectionHeading
# 33
# ## Industry Trends
# sectionHeading
# 33
# ## Economic Conditions, Challenges, and Risks
# sectionHeading
# 33
# ## Seasonality
# pageNumber
# 33
# <!-- PageNumber="33" -->
# sectionHeading
# 34
# ## Change in Accounting Estimate
# sectionHeading
# 34
# ## Reportable Segments
# sectionHeading
# 34
# ### Metrics
# sectionHeading
# 34
# ## Commercial
# pageNumber
# 34
# <!-- PageNumber="34" -->
# sectionHeading
# 35
# ## Productivity and Business Processes and Intelligent Cloud
# sectionHeading
# 35
# ### More Personal Computing
# pageNumber
# 35
# <!-- PageNumber="35" -->
# pageHeader
# 36
# <!-- PageHeader="PART ! Item 2" -->
# title
# 36
# SUMMARY RESULTS OF OPERATIONS
# ===
# sectionHeading
# 36
# ## Three Months Ended March 31, 2023 Compared with Three Months Ended March 31, 2022
# sectionHeading
# 36
# ## Key changes in operating expenses were:
# pageNumber
# 36
# <!-- PageNumber="36" -->
# pageHeader
# 37
# <!-- PageHeader="PART ! Item 2" -->
# sectionHeading
# 37
# ## Nine Months Ended March 31, 2023 Compared with Nine Months Ended March 31, 2022
# pageNumber
# 37
# <!-- PageNumber="37" -->
# pageHeader
# 38
# <!-- PageHeader="PART ! Item 2" -->
# title
# 38
# SEGMENT RESULTS OF OPERATIONS
# ===
# sectionHeading
# 38
# ## Reportable Segments Three Months Ended March 31, 2023 Compared with Three Months Ended March 31, 2022
# sectionHeading
# 38
# ## Intelligent Cloud
# pageNumber
# 38
# <!-- PageNumber="38" -->
# pageHeader
# 39
# <!-- PageHeader="PART ! Item 2" -->
# sectionHeading
# 39
# ### More Personal Computing
# sectionHeading
# 39
# ### Nine Months Ended March 31, 2023 Compared with Nine Months Ended March 31, 2022
# sectionHeading
# 39
# ### Productivity and Business Processes
# pageNumber
# 39
# <!-- PageNumber="39" -->
# pageHeader
# 40
# <!-- PageHeader="PART ! Item 2" -->
# sectionHeading
# 40
# ### Intelligent Cloud
# sectionHeading
# 40
# ## More Personal Computing
# pageNumber
# 40
# <!-- PageNumber="40" -->
# pageHeader
# 41
# <!-- PageHeader="PART ! Item 2" -->
# sectionHeading
# 41
# ## Research and Development
# sectionHeading
# 41
# ## OPERATING EXPENSES
# sectionHeading
# 41
# ## Three Months Ended March 31, 2023 Compared with Three Months Ended March 31, 2022
# sectionHeading
# 41
# ## Nine Months Ended March 31, 2023 Compared with Nine Months Ended March 31, 2022
# sectionHeading
# 41
# ## Sales and Marketing
# sectionHeading
# 41
# ## Three Months Ended March 31, 2023 Compared with Three Months Ended March 31, 2022
# sectionHeading
# 41
# ### Nine Months Ended March 31, 2023 Compared with Nine Months Ended March 31, 2022
# sectionHeading
# 41
# ## General and Administrative
# pageNumber
# 41
# <!-- PageNumber="41" -->
# pageHeader
# 42
# <!-- PageHeader="PART ! Item 2" -->
# sectionHeading
# 42
# ## Three Months Ended March 31, 2023 Compared with Three Months Ended March 31, 2022
# sectionHeading
# 42
# ### Nine Months Ended March 31, 2023 Compared with Nine Months Ended March 31, 2022
# sectionHeading
# 42
# ### Three Months Ended March 31, 2023 Compared with Three Months Ended March 31, 2022
# sectionHeading
# 42
# ## Nine Months Ended March 31, 2023 Compared with Nine Months Ended March 31, 2022
# pageNumber
# 42
# <!-- PageNumber="42" -->
# pageHeader
# 43
# <!-- PageHeader="PART ! Item 2" -->
# title
# 43
# INCOME TAXES
# ===
# sectionHeading
# 43
# ## Effective Tax Rate
# sectionHeading
# 43
# ### Uncertain Tax Positions
# sectionHeading
# 43
# ## NON-GAAP FINANCIAL MEASURES
# pageNumber
# 43
# <!-- PageNumber="43" -->
# pageHeader
# 44
# <!-- PageHeader="PART ! Item 2" -->
# sectionHeading
# 44
# ## LIQUIDITY AND CAPITAL RESOURCES
# sectionHeading
# 44
# ## Cash, Cash Equivalents, and Investments
# pageNumber
# 44
# <!-- PageNumber="44" -->
# pageHeader
# 45
# <!-- PageHeader="PART ! Item 2" -->
# sectionHeading
# 45
# ## Valuation
# sectionHeading
# 45
# ## Cash Flows
# sectionHeading
# 45
# ## Debt Proceeds
# sectionHeading
# 45
# ## Unearned Revenue
# pageNumber
# 45
# <!-- PageNumber="45" -->
# pageHeader
# 46
# <!-- PageHeader="PART ! Item 2" -->
# sectionHeading
# 46
# ## (In millions)
# sectionHeading
# 46
# ## Material Cash Requirements and Other Obligations
# sectionHeading
# 46
# ### Income Taxes
# sectionHeading
# 46
# ## Share Repurchases
# sectionHeading
# 46
# ## Dividends
# sectionHeading
# 46
# ## Other Planned Uses of Capital
# pageNumber
# 46
# <!-- PageNumber="46" -->
# pageHeader
# 47
# <!-- PageHeader="PART ! Item 2" -->
# sectionHeading
# 47
# ## CRITICAL ACCOUNTING ESTIMATES
# sectionHeading
# 47
# ## Revenue Recognition
# pageNumber
# 47
# <!-- PageNumber="47" -->
# pageHeader
# 48
# <!-- PageHeader="PART I Item 2" -->
# sectionHeading
# 48
# ## Impairment of Investment Securities
# sectionHeading
# 48
# ## Goodwill
# sectionHeading
# 48
# ### Research and Development Costs
# sectionHeading
# 48
# ## Legal and Other Contingencies
# pageNumber
# 48
# <!-- PageNumber="48" -->
# sectionHeading
# 49
# ## Income Taxes
# sectionHeading
# 49
# ## Inventories
# pageNumber
# 49
# <!-- PageNumber="49" -->
# pageHeader
# 50
# <!-- PageHeader="PART I Item 3, 4" -->
# title
# 50
# ITEM 3. QUANTITATIVE AND QUALITATIVE DISCLOSURES ABOUT MARKET RISK
# ===
# sectionHeading
# 50
# ## RISKS
# sectionHeading
# 50
# ## Foreign Currencies
# sectionHeading
# 50
# ## Interest Rate
# sectionHeading
# 50
# ## Credit
# sectionHeading
# 50
# ## Equity
# sectionHeading
# 50
# ## SENSITIVITY ANALYSIS
# sectionHeading
# 50
# ## ITEM 4. CONTROLS AND PROCEDURES
# pageNumber
# 50
# <!-- PageNumber="50" -->
# pageHeader
# 51
# <!-- PageHeader="PART II Item 1, 1A" -->
# title
# 51
# PART II. OTHER INFORMATION ITEM 1. LEGAL PROCEEDINGS
# ===
# sectionHeading
# 51
# ## ITEM 1A. RISK FACTORS
# sectionHeading
# 51
# ## STRATEGIC AND COMPETITIVE RISKS
# sectionHeading
# 51
# ### Competition among platform-based ecosystems
# pageNumber
# 51
# <!-- PageNumber="51" -->
# pageHeader
# 52
# <!-- PageHeader="PART II Item 1A" -->
# sectionHeading
# 52
# ## Business model competition
# pageNumber
# 52
# <!-- PageNumber="52" -->
# pageHeader
# 53
# <!-- PageHeader="PART II Item 1A" -->
# sectionHeading
# 53
# ## RISKS RELATING TO THE EVOLUTION OF OUR BUSINESS
# pageNumber
# 53
# <!-- PageNumber="53" -->
# pageHeader
# 54
# <!-- PageHeader="PART II Item 1A" -->
# sectionHeading
# 54
# ## CYBERSECURITY, DATA PRIVACY, AND PLATFORM ABUSE RISKS
# sectionHeading
# 54
# ### Security of our information technology
# pageNumber
# 54
# <!-- PageNumber="54" -->
# pageHeader
# 55
# <!-- PageHeader="PART II Item 1A" -->
# sectionHeading
# 55
# ### Security of our products, services, devices, and customers' data
# pageNumber
# 55
# <!-- PageNumber="55" -->
# pageHeader
# 56
# <!-- PageHeader="PART II Item 1A" -->
# sectionHeading
# 56
# ## Development and deployment of defensive measures
# pageNumber
# 56
# <!-- PageNumber="56" -->
# pageHeader
# 57
# <!-- PageHeader="PART II Item 1A" -->
# sectionHeading
# 57
# ## Abuse of our platforms may harm our reputation or user engagement.
# sectionHeading
# 57
# ### Advertising, professional, marketplace, and gaming platform abuses
# sectionHeading
# 57
# #### Other digital safety abuses
# pageNumber
# 57
# <!-- PageNumber="57" -->
# pageHeader
# 58
# <!-- PageHeader="PART II Item 1A" -->
# sectionHeading
# 58
# ## OPERATIONAL RISKS
# sectionHeading
# 58
# ## LEGAL, REGULATORY, AND LITIGATION RISKS
# pageNumber
# 58
# <!-- PageNumber="58" -->
# pageHeader
# 59
# <!-- PageHeader="PART II Item 1A" -->
# pageNumber
# 59
# <!-- PageNumber="59" -->
# pageHeader
# 60
# <!-- PageHeader="PART II Item 1A" -->
# sectionHeading
# 60
# ### Cross-border transfer of personal data
# pageNumber
# 60
# <!-- PageNumber="60" -->
# pageHeader
# 61
# <!-- PageHeader="PART II Item 1A" -->
# sectionHeading
# 61
# ## Other laws and regulations relating to the handling of personal data
# pageNumber
# 61
# <!-- PageNumber="61" -->
# pageHeader
# 62
# <!-- PageHeader="PART II Item 1A" -->
# sectionHeading
# 62
# ## INTELLECTUAL PROPERTY RISKS
# pageNumber
# 62
# <!-- PageNumber="62" -->
# pageHeader
# 63
# <!-- PageHeader="PART II Item 1A" -->
# sectionHeading
# 63
# ## GENERAL RISKS
# pageNumber
# 63
# <!-- PageNumber="63" -->
# pageHeader
# 64
# <!-- PageHeader="PART II Item 1A" -->
# pageNumber
# 64
# <!-- PageNumber="64" -->
# pageHeader
# 65
# <!-- PageHeader="PART II Item 1A" -->
# pageNumber
# 65
# <!-- PageNumber="65" -->
# title
# 66
# PART II Item 2
# ===
# title
# 66
# ITEM 2. UNREGISTERED SALES OF EQUITY SECURITIES AND USE OF PROCEEDS SHARE REPURCHASES AND DIVIDENDS
# ===
# pageNumber
# 66
# <!-- PageNumber="66" -->
# title
# 67
# ITEM 6. EXHIBITS
# ===
# pageNumber
# 67
# <!-- PageNumber="67" -->
# title
# 68
# SIGNATURE
# ===
# pageNumber
# 68
# <!-- PageNumber="68" -->
# pageNumber
# 69
# <!-- PageNumber="Exhibit 15.1" -->
# pageHeader
# 69
# <!-- PageHeader="April 25, 2023" -->
# pageHeader
# 70
# <!-- PageHeader="Exhibit 31.1" -->
# title
# 70
# CERTIFICATION
# ===
# title
# 71
# CERTIFICATION
# ===
# pageHeader
# 72
# <!-- PageHeader="Exhibit 32.1" -->
# title
# 72
# CERTIFICATION PURSUANT TO SECTION 906 OF THE SARBANES-OXLEY ACT OF 2002 (18 U.S.C. SECTION 1350)
# ===
# pageHeader
# 73
# <!-- PageHeader="Exhibit 32.2" -->
# title
# 73
# CERTIFICATION PURSUANT TO SECTION 906 OF THE SARBANES-OXLEY ACT OF 2002 (18 U.S.C. SECTION 1350)
# ===
# [{'spans': [{'offset': 0, 'length': 75}], 'boundingRegions': [{'pageNumber': 1, 'polygon': [1.719, 0.4106, 6.5006, 0.4106, 6.5006, 1.0748, 1.719, 1.0748]}], 'role': 'title', 'content': 'UNITED STATES SECURITIES AND EXCHANGE COMMISSION Washington, D.C. 20549\n==='},
#  {'spans': [{'offset': 77, 'length': 9}], 'boundingRegions': [{'pageNumber': 1, 'polygon': [3.4937, 1.237, 4.7411, 1.237, 4.7411, 1.4702, 3.4937, 1.4702]}], 'content': 'FORM 10-Q'},
#  {'spans': [{'offset': 88, 'length': 144}], 'boundingRegions': [{'pageNumber': 1, 'polygon': [0.2393, 1.6137, 7.0025, 1.5832, 7.0041, 1.9533, 0.241, 1.9837]}], 'content': ':selected:\nQUARTERLY REPORT PURSUANT TO SECTION 13 OR 15(d) OF THE SECURITIES EXCHANGE ACT OF 1934 For the Quarterly Period Ended March 31, 2023'},
#  {'spans': [{'offset': 234, 'length': 2}], 'boundingRegions': [{'pageNumber': 1, 'polygon': [4.1833, 2.0634, 4.4064, 2.0634, 4.4014, 2.185, 4.1833, 2.1901]}], 'content': 'OR'},
#  {'spans': [{'offset': 238, 'length': 12}], 'boundingRegions': [{'pageNumber': 1, 'polygon': [0.2427, 2.309, 0.3451, 2.309, 0.3451, 2.4117, 0.2427, 2.4117]}], 'content': ':unselected:'},
#  {'spans': [{'offset': 251, 'length': 88}], 'boundingRegions': [{'pageNumber': 1, 'polygon': [0.5679, 2.2814, 7.0026, 2.2814, 7.0026, 2.4334, 0.5679, 2.4385]}], 'content': 'TRANSITION REPORT PURSUANT TO SECTION 13 OR 15(d) OF THE SECURITIES EXCHANGE ACT OF 1934'},
#  {'spans': [{'offset': 341, 'length': 30}], 'boundingRegions': [{'pageNumber': 1, 'polygon': [0.573, 2.5298, 2.0536, 2.5298, 2.0536, 2.6464, 0.573, 2.6514]}], 'content': 'For the Transition Period From'},
#  {'spans': [{'offset': 373, 'length': 2}], 'boundingRegions': [{'pageNumber': 1, 'polygon': [2.5353, 2.545, 2.6418, 2.545, 2.6418, 2.6362, 2.5303, 2.6312]}], 'content': 'to'},
#  {'spans': [{'offset': 377, 'length': 32}], 'boundingRegions': [{'pageNumber': 1, 'polygon': [3.037, 2.6768, 5.1974, 2.6717, 5.1978, 2.8187, 3.0373, 2.8238]}], 'content': 'Commission File Number 001-37845'},
#  {'spans': [{'offset': 412, 'length': 24}], 'boundingRegions': [{'pageNumber': 1, 'polygon': [2.0587, 2.9911, 6.1761, 2.9911, 6.1761, 3.2547, 2.0587, 3.2547]}], 'role': 'sectionHeading', 'content': '## MICROSOFT CORPORATION'},
#  {'spans': [{'offset': 438, 'length': 35}], 'boundingRegions': [{'pageNumber': 1, 'polygon': [1.4585, 3.4496, 2.798, 3.4395, 2.7999, 3.6806, 1.4604, 3.6907]}], 'content': 'WASHINGTON (STATE OF INCORPORATION)'},
#  {'spans': [{'offset': 475, 'length': 22}], 'boundingRegions': [{'pageNumber': 1, 'polygon': [5.8059, 3.4423, 6.4043, 3.4423, 6.4043, 3.6907, 5.8059, 3.6907]}], 'content': '91-1144442 (I.R.S. ID)'},
#  {'spans': [{'offset': 499, 'length': 91}], 'boundingRegions': [{'pageNumber': 1, 'polygon': [2.5303, 3.7364, 5.7045, 3.7364, 5.7045, 4.0862, 2.5303, 4.0862]}], 'content': 'ONE MICROSOFT WAY, REDMOND, WASHINGTON 98052-6399 (425) 882-8080 www.microsoft.com/investor'},
#  {'spans': [{'offset': 592, 'length': 59}], 'boundingRegions': [{'pageNumber': 1, 'polygon': [0.2231, 4.1673, 2.9359, 4.1673, 2.9359, 4.2839, 0.2231, 4.289]}], 'content': 'Securities registered pursuant to Section 12(b) of the Act:'},
#  {'spans': [{'offset': 655, 'length': 19}], 'boundingRegions': [{'pageNumber': 1, 'polygon': [0.1717, 4.3115, 3.23, 4.3115, 3.23, 4.494, 0.1717, 4.494]}], 'content': 'Title of each class'},
#  {'spans': [{'offset': 677, 'length': 14}], 'boundingRegions': [{'pageNumber': 1, 'polygon': [3.23, 4.3115, 4.9818, 4.3115, 4.9818, 4.494, 3.23, 4.494]}], 'content': 'Trading Symbol'},
#  {'spans': [{'offset': 694, 'length': 36}], 'boundingRegions': [{'pageNumber': 1, 'polygon': [4.9818, 4.3115, 7.4707, 4.3115, 7.4634, 4.5013, 4.9818, 4.494]}], 'content': 'Name of exchange on which registered'},
#  {'spans': [{'offset': 749, 'length': 45}], 'boundingRegions': [{'pageNumber': 1, 'polygon': [0.1717, 4.494, 3.23, 4.494, 3.23, 4.6473, 0.1644, 4.6473]}], 'content': 'Common stock, $0.00000625 par value per share'},
#  {'spans': [{'offset': 797, 'length': 4}], 'boundingRegions': [{'pageNumber': 1, 'polygon': [3.23, 4.494, 4.9818, 4.494, 4.9818, 4.6473, 3.23, 4.6473]}], 'content': 'MSFT'},
#  {'spans': [{'offset': 804, 'length': 6}], 'boundingRegions': [{'pageNumber': 1, 'polygon': [4.9818, 4.494, 7.4634, 4.5013, 7.4634, 4.6546, 4.9818, 4.6473]}], 'content': 'NASDAQ'},
#  {'spans': [{'offset': 815, 'length': 21}], 'boundingRegions': [{'pageNumber': 1, 'polygon': [0.1644, 4.6473, 3.23, 4.6473, 3.23, 4.7787, 0.1644, 4.7787]}], 'content': '3.125% Notes due 2028'},
#  {'spans': [{'offset': 839, 'length': 4}], 'boundingRegions': [{'pageNumber': 1, 'polygon': [3.23, 4.6473, 4.9818, 4.6473, 4.9818, 4.7787, 3.23, 4.7787]}], 'content': 'MSFT'},
#  {'spans': [{'offset': 846, 'length': 6}], 'boundingRegions': [{'pageNumber': 1, 'polygon': [4.9818, 4.6473, 7.4634, 4.6546, 7.4634, 4.7787, 4.9818, 4.7787]}], 'content': 'NASDAQ'},
#  {'spans': [{'offset': 857, 'length': 21}], 'boundingRegions': [{'pageNumber': 1, 'polygon': [0.1644, 4.7787, 3.23, 4.7787, 3.2227, 4.9466, 0.1644, 4.9466]}], 'content': '2.625% Notes due 2033'},
#  {'spans': [{'offset': 881, 'length': 4}], 'boundingRegions': [{'pageNumber': 1, 'polygon': [3.23, 4.7787, 4.9818, 4.7787, 4.9818, 4.9466, 3.2227, 4.9466]}], 'content': 'MSFT'},
#  {'spans': [{'offset': 888, 'length': 6}], 'boundingRegions': [{'pageNumber': 1, 'polygon': [4.9818, 4.7787, 7.4634, 4.7787, 7.4561, 4.9539, 4.9818, 4.9466]}], 'content': 'NASDAQ'},
#  {'spans': [{'offset': 898, 'length': 377}], 'boundingRegions': [{'pageNumber': 1, 'polygon': [0.2079, 4.9632, 8.0117, 4.9632, 8.0117, 5.313, 0.2079, 5.313]}], 'content': 'Indicate by check mark whether the registrant (1) has filed all reports required to be filed by Section 13 or 15(d) of the Securities Exchange Act of 1934 during the preceding 12 months (or for such shorter period that the registrant was required to file such reports), and (2) has been subject to such filing requirements for the past 90 days. Yes X :selected: :unselected: No'},
#  {'spans': [{'offset': 1277, 'length': 326}, {'offset': 1605, 'length': 12}], 'boundingRegions': [{'pageNumber': 1, 'polygon': [0.213, 5.3688, 8.0117, 5.3688, 8.0117, 5.6172, 0.213, 5.6172]}], 'content': 'Indicate by check mark whether the registrant has submitted electronically every Interactive Data File required to be submitted pursuant to Rule 405 of Regulation S-T (§232.405 of this chapter) during the preceding 12 months (or for such shorter period that the registrant was required to submit such files). Yes :selected: No\n:unselected:'},
#  {'spans': [{'offset': 1618, 'length': 347}], 'boundingRegions': [{'pageNumber': 1, 'polygon': [0.2079, 5.6527, 8.0218, 5.6527, 8.0218, 5.9974, 0.2079, 5.9974]}], 'content': 'Indicate by check mark whether the registrant is a large accelerated filer, an accelerated filer, a non-accelerated filer, a smaller reporting company, or an emerging growth company. See the definitions of "large accelerated filer," "accelerated filer," "smaller reporting company," and "emerging growth company" in Rule 12b-2 of the Exchange Act.'},
#  {'spans': [{'offset': 1967, 'length': 25}], 'boundingRegions': [{'pageNumber': 1, 'polygon': [0.2282, 6.0735, 1.4451, 6.0684, 1.4451, 6.1799, 0.2282, 6.1901]}], 'content': 'Large Accelerated Filer X'},
#  {'spans': [{'offset': 1994, 'length': 10}], 'boundingRegions': [{'pageNumber': 1, 'polygon': [1.3632, 6.0803, 1.4488, 6.0803, 1.4488, 6.1661, 1.3632, 6.1661]}], 'content': ':selected:'},
#  {'spans': [{'offset': 2005, 'length': 21}, {'offset': 2028, 'length': 12}], 'boundingRegions': [{'pageNumber': 1, 'polygon': [0.2282, 6.2256, 1.3694, 6.2256, 1.3694, 6.3371, 0.2282, 6.3371]}], 'content': 'Non-accelerated Filer\n:unselected:'},
#  {'spans': [{'offset': 2041, 'length': 56}, {'offset': 2099, 'length': 12}], 'boundingRegions': [{'pageNumber': 1, 'polygon': [6.0088, 6.0622, 7.482, 6.0732, 7.48, 6.348, 6.0068, 6.3371]}], 'content': 'Accelerated Filer :unselected: Smaller Reporting Company\n:unselected:'},
#  {'spans': [{'offset': 2112, 'length': 23}], 'boundingRegions': [{'pageNumber': 1, 'polygon': [6.0189, 6.3625, 7.353, 6.3675, 7.3525, 6.4993, 6.0184, 6.4943]}], 'content': 'Emerging Growth Company'},
#  {'spans': [{'offset': 2137, 'length': 12}], 'boundingRegions': [{'pageNumber': 1, 'polygon': [7.3687, 6.3802, 7.4558, 6.3802, 7.4558, 6.4675, 7.3687, 6.4675]}], 'content': ':unselected:'},
#  {'spans': [{'offset': 2150, 'length': 265}], 'boundingRegions': [{'pageNumber': 1, 'polygon': [0.2079, 6.5551, 8.0218, 6.5551, 8.0218, 6.8035, 0.2079, 6.8035]}], 'content': 'If an emerging growth company, indicate by check mark if the registrant has elected not to use the extended transition period for complying with any new or revised financial accounting standards provided pursuant to Section 13(a) of the Exchange Act. :unselected: ☐'},
#  {'spans': [{'offset': 2417, 'length': 132}], 'boundingRegions': [{'pageNumber': 1, 'polygon': [0.218, 6.8593, 6.2369, 6.8593, 6.2369, 6.9911, 0.218, 6.9911]}], 'content': 'Indicate by check mark whether the registrant is a shell company (as defined in Rule 12b-2 of the Exchange Act). Yes :unselected: No'},
#  {'spans': [{'offset': 2551, 'length': 10}], 'boundingRegions': [{'pageNumber': 1, 'polygon': [6.2852, 6.8787, 6.3709, 6.8787, 6.3709, 6.9618, 6.2852, 6.9618]}], 'content': ':selected:'},
#  {'spans': [{'offset': 2562, 'length': 125}], 'boundingRegions': [{'pageNumber': 1, 'polygon': [0.213, 7.0317, 6.0392, 7.0317, 6.0392, 7.1533, 0.213, 7.1533]}], 'content': "Indicate the number of shares outstanding of each of the issuer's classes of common stock, as of the latest practicable date."},
#  {'spans': [{'offset': 2689, 'length': 5}], 'boundingRegions': [{'pageNumber': 1, 'polygon': [0.2282, 7.2142, 0.502, 7.2142, 0.502, 7.3105, 0.2282, 7.3105]}], 'content': 'Class'},
#  {'spans': [{'offset': 2696, 'length': 32}], 'boundingRegions': [{'pageNumber': 1, 'polygon': [6.4093, 7.2091, 7.8596, 7.2091, 7.8596, 7.3206, 6.4093, 7.3257]}], 'content': 'Outstanding as of April 20, 2023'},
#  {'spans': [{'offset': 2730, 'length': 45}], 'boundingRegions': [{'pageNumber': 1, 'polygon': [0.218, 7.4372, 2.5914, 7.4423, 2.5911, 7.564, 0.2178, 7.5589]}], 'content': 'Common Stock, $0.00000625 par value per share'},
#  {'spans': [{'offset': 2777, 'length': 20}], 'boundingRegions': [{'pageNumber': 1, 'polygon': [6.815, 7.4322, 7.8703, 7.4372, 7.8697, 7.5538, 6.8144, 7.5488]}], 'content': '7,435,487,575 shares'},
#  {'spans': [{'offset': 2799, 'length': 78}], 'boundingRegions': [{'pageNumber': 2, 'polygon': [2.9816, 0.2332, 5.2532, 0.2332, 5.2532, 0.9531, 2.9816, 0.9531]}], 'role': 'title', 'content': 'MICROSOFT CORPORATION FORM 10-Q For the Quarter Ended March 31, 2023 INDEX\n==='},
#  {'spans': [{'offset': 2881, 'length': 29}], 'boundingRegions': [{'pageNumber': 2, 'polygon': [0.1641, 1.039, 7.5707, 1.055, 7.5787, 1.4632, 0.1641, 1.4632]}], 'content': 'PART I. FINANCIAL INFORMATION'},
#  {'spans': [{'offset': 2915, 'length': 4}], 'boundingRegions': [{'pageNumber': 2, 'polygon': [7.5707, 1.055, 8.1152, 1.063, 8.1152, 1.2151, 7.5707, 1.2151]}], 'content': 'Page'},
#  {'spans': [{'offset': 2949, 'length': 7}], 'boundingRegions': [{'pageNumber': 2, 'polygon': [0.1641, 1.4632, 1.4693, 1.4632, 1.4693, 1.7753, 0.1641, 1.7833]}], 'content': 'Item 1.'},
#  {'spans': [{'offset': 2960, 'length': 20}], 'boundingRegions': [{'pageNumber': 2, 'polygon': [1.4693, 1.4632, 7.5787, 1.4632, 7.5787, 1.7753, 1.4693, 1.7753]}], 'content': 'Financial Statements'},
#  {'spans': [{'offset': 2990, 'length': 80}], 'boundingRegions': [{'pageNumber': 2, 'polygon': [1.4693, 1.7753, 7.5787, 1.7753, 7.5787, 1.9914, 1.4693, 1.9914]}], 'content': 'a) Income Statements for the Three and Nine Months Ended March 31, 2023 and 2022'},
#  {'spans': [{'offset': 3073, 'length': 1}], 'boundingRegions': [{'pageNumber': 2, 'polygon': [7.5787, 1.7753, 8.1152, 1.7673, 8.1152, 1.9834, 7.5787, 1.9914]}], 'content': '3'},
#  {'spans': [{'offset': 3082, 'length': 94}], 'boundingRegions': [{'pageNumber': 2, 'polygon': [1.4693, 1.9914, 7.5787, 1.9914, 7.5787, 2.3196, 1.4693, 2.3276]}], 'content': 'b) Comprehensive Income Statements for the Three and Nine Months Ended March 31, 2023 and 2022'},
#  {'spans': [{'offset': 3179, 'length': 1}], 'boundingRegions': [{'pageNumber': 2, 'polygon': [7.5787, 1.9914, 8.1152, 1.9834, 8.1152, 2.3196, 7.5787, 2.3196]}], 'content': '4'},
#  {'spans': [{'offset': 3188, 'length': 56}], 'boundingRegions': [{'pageNumber': 2, 'polygon': [1.4693, 2.3276, 7.5787, 2.3196, 7.5787, 2.7278, 1.4693, 2.7278]}], 'content': 'c) Balance Sheets as of March 31, 2023 and June 30, 2022'},
#  {'spans': [{'offset': 3247, 'length': 3}], 'boundingRegions': [{'pageNumber': 2, 'polygon': [7.5787, 2.3196, 8.1152, 2.3196, 8.1152, 2.7278, 7.5787, 2.7278]}], 'content': '5 5'},
#  {'spans': [{'offset': 3258, 'length': 84}], 'boundingRegions': [{'pageNumber': 2, 'polygon': [1.4693, 2.7278, 7.5787, 2.7278, 7.5787, 3.0479, 1.4693, 3.0479]}], 'content': 'd) Cash Flows Statements for the Three and Nine Months Ended March 31, 2023 and 2022'},
#  {'spans': [{'offset': 3345, 'length': 1}], 'boundingRegions': [{'pageNumber': 2, 'polygon': [7.5787, 2.7278, 8.1152, 2.7278, 8.1152, 3.0559, 7.5787, 3.0479]}], 'content': '6'},
#  {'spans': [{'offset': 3354, 'length': 94}], 'boundingRegions': [{'pageNumber': 2, 'polygon': [1.4693, 3.0479, 7.5787, 3.0479, 7.5787, 3.272, 1.4693, 3.264]}], 'content': "e) Stockholders' Equity Statements for the Three and Nine Months Ended March 31, 2023 and 2022"},
#  {'spans': [{'offset': 3451, 'length': 1}], 'boundingRegions': [{'pageNumber': 2, 'polygon': [7.5787, 3.0479, 8.1152, 3.0559, 8.1152, 3.272, 7.5787, 3.272]}], 'content': '7'},
#  {'spans': [{'offset': 3460, 'length': 32}], 'boundingRegions': [{'pageNumber': 2, 'polygon': [1.4693, 3.264, 7.5787, 3.272, 7.5787, 3.6882, 1.4693, 3.6802]}], 'content': 'f) Notes to Financial Statements'},
#  {'spans': [{'offset': 3495, 'length': 1}], 'boundingRegions': [{'pageNumber': 2, 'polygon': [7.5787, 3.272, 8.1152, 3.272, 8.1152, 3.6882, 7.5787, 3.6882]}], 'content': '8'},
#  {'spans': [{'offset': 3504, 'length': 58}], 'boundingRegions': [{'pageNumber': 2, 'polygon': [1.4693, 3.6802, 7.5787, 3.6882, 7.5787, 3.9924, 1.4693, 3.9924]}], 'content': 'g) Report of Independent Registered Public Accounting Firm'},
#  {'spans': [{'offset': 3565, 'length': 2}], 'boundingRegions': [{'pageNumber': 2, 'polygon': [7.5787, 3.6882, 8.1152, 3.6882, 8.1232, 3.9924, 7.5787, 3.9924]}], 'content': '31'},
#  {'spans': [{'offset': 3572, 'length': 7}], 'boundingRegions': [{'pageNumber': 2, 'polygon': [0.1641, 3.9924, 1.4693, 3.9924, 1.4693, 4.2165, 0.1641, 4.2165]}], 'content': 'Item 2.'},
#  {'spans': [{'offset': 3583, 'length': 85}], 'boundingRegions': [{'pageNumber': 2, 'polygon': [1.4693, 3.9924, 7.5787, 3.9924, 7.5787, 4.2245, 1.4693, 4.2165]}], 'content': "Management's Discussion and Analysis of Financial Condition and Results of Operations"},
#  {'spans': [{'offset': 3671, 'length': 2}], 'boundingRegions': [{'pageNumber': 2, 'polygon': [7.5787, 3.9924, 8.1232, 3.9924, 8.1232, 4.2245, 7.5787, 4.2245]}], 'content': '32'},
#  {'spans': [{'offset': 3678, 'length': 7}], 'boundingRegions': [{'pageNumber': 2, 'polygon': [0.1641, 4.2165, 1.4693, 4.2165, 1.4693, 4.6407, 0.1641, 4.6487]}], 'content': 'Item 3.'},
#  {'spans': [{'offset': 3689, 'length': 58}], 'boundingRegions': [{'pageNumber': 2, 'polygon': [1.4693, 4.2165, 7.5787, 4.2245, 7.5787, 4.6407, 1.4693, 4.6407]}], 'content': 'Quantitative and Qualitative Disclosures About Market Risk'},
#  {'spans': [{'offset': 3750, 'length': 2}], 'boundingRegions': [{'pageNumber': 2, 'polygon': [7.5787, 4.2245, 8.1232, 4.2245, 8.1232, 4.6487, 7.5787, 4.6407]}], 'content': '50'},
#  {'spans': [{'offset': 3757, 'length': 7}], 'boundingRegions': [{'pageNumber': 2, 'polygon': [0.1641, 4.6487, 1.4693, 4.6407, 1.4693, 4.9608, 0.1641, 4.9608]}], 'content': 'Item 4.'},
#  {'spans': [{'offset': 3768, 'length': 23}], 'boundingRegions': [{'pageNumber': 2, 'polygon': [1.4693, 4.6407, 7.5787, 4.6407, 7.5787, 4.9608, 1.4693, 4.9608]}], 'content': 'Controls and Procedures'},
#  {'spans': [{'offset': 3794, 'length': 2}], 'boundingRegions': [{'pageNumber': 2, 'polygon': [7.5787, 4.6407, 8.1232, 4.6487, 8.1232, 4.9688, 7.5787, 4.9608]}], 'content': '50'},
#  {'spans': [{'offset': 3801, 'length': 8}], 'boundingRegions': [{'pageNumber': 2, 'polygon': [0.1641, 4.9608, 0.8207, 4.9608, 0.8207, 5.265, 0.1641, 5.273]}], 'content': 'PART II.'},
#  {'spans': [{'offset': 3812, 'length': 17}], 'boundingRegions': [{'pageNumber': 2, 'polygon': [0.8207, 4.9608, 7.5787, 4.9608, 7.5787, 5.273, 0.8207, 5.265]}], 'content': 'OTHER INFORMATION'},
#  {'spans': [{'offset': 3837, 'length': 7}], 'boundingRegions': [{'pageNumber': 2, 'polygon': [0.1641, 5.273, 1.4693, 5.265, 1.4693, 5.5931, 0.1641, 5.6011]}], 'content': 'Item 1.'},
#  {'spans': [{'offset': 3848, 'length': 17}], 'boundingRegions': [{'pageNumber': 2, 'polygon': [1.4693, 5.265, 7.5787, 5.273, 7.5787, 5.6011, 1.4693, 5.5931]}], 'content': 'Legal Proceedings'},
#  {'spans': [{'offset': 3868, 'length': 2}], 'boundingRegions': [{'pageNumber': 2, 'polygon': [7.5787, 5.273, 8.1232, 5.273, 8.1232, 5.6091, 7.5787, 5.6011]}], 'content': '51'},
#  {'spans': [{'offset': 3875, 'length': 8}], 'boundingRegions': [{'pageNumber': 2, 'polygon': [0.1641, 5.6011, 1.4693, 5.5931, 1.4693, 5.9133, 0.1641, 5.9133]}], 'content': 'Item 1A.'},
#  {'spans': [{'offset': 3887, 'length': 12}], 'boundingRegions': [{'pageNumber': 2, 'polygon': [1.4693, 5.5931, 7.5787, 5.6011, 7.5787, 5.9213, 1.4693, 5.9133]}], 'content': 'Risk Factors'},
#  {'spans': [{'offset': 3902, 'length': 2}], 'boundingRegions': [{'pageNumber': 2, 'polygon': [7.5787, 5.6011, 8.1232, 5.6091, 8.1232, 5.9213, 7.5787, 5.9213]}], 'content': '51'},
#  {'spans': [{'offset': 3909, 'length': 7}], 'boundingRegions': [{'pageNumber': 2, 'polygon': [0.1641, 5.9133, 1.4693, 5.9133, 1.4693, 6.1294, 0.1641, 6.1294]}], 'content': 'Item 2.'},
#  {'spans': [{'offset': 3920, 'length': 59}], 'boundingRegions': [{'pageNumber': 2, 'polygon': [1.4693, 5.9133, 7.5787, 5.9213, 7.5787, 6.1454, 1.4693, 6.1294]}], 'content': 'Unregistered Sales of Equity Securities and Use of Proceeds'},
#  {'spans': [{'offset': 3982, 'length': 2}], 'boundingRegions': [{'pageNumber': 2, 'polygon': [7.5787, 5.9213, 8.1232, 5.9213, 8.1232, 6.1454, 7.5787, 6.1454]}], 'content': '66'},
#  {'spans': [{'offset': 3989, 'length': 7}], 'boundingRegions': [{'pageNumber': 2, 'polygon': [0.1641, 6.1294, 1.4693, 6.1294, 1.4693, 6.5375, 0.1641, 6.5295]}], 'content': 'Item 6.'},
#  {'spans': [{'offset': 4000, 'length': 8}], 'boundingRegions': [{'pageNumber': 2, 'polygon': [1.4693, 6.1294, 7.5787, 6.1454, 7.5867, 6.5535, 1.4693, 6.5375]}], 'content': 'Exhibits'},
#  {'spans': [{'offset': 4011, 'length': 2}], 'boundingRegions': [{'pageNumber': 2, 'polygon': [7.5787, 6.1454, 8.1232, 6.1454, 8.1232, 6.5535, 7.5867, 6.5535]}], 'content': '67'},
#  {'spans': [{'offset': 4018, 'length': 9}], 'boundingRegions': [{'pageNumber': 2, 'polygon': [0.1641, 6.5295, 1.4693, 6.5375, 1.4693, 6.8097, 0.1641, 6.8097]}], 'content': 'SIGNATURE'},
#  {'spans': [{'offset': 4033, 'length': 2}], 'boundingRegions': [{'pageNumber': 2, 'polygon': [7.5867, 6.5535, 8.1232, 6.5535, 8.1232, 6.8257, 7.5867, 6.8177]}], 'content': '68'},
#  {'spans': [{'offset': 4039, 'length': 23}], 'boundingRegions': [{'pageNumber': 2, 'polygon': [4.0819, 7.2446, 4.1479, 7.2485, 4.1428, 7.3346, 4.0768, 7.3308]}], 'role': 'pageNumber', 'content': '<!-- PageNumber="2" -->'},
#  {'spans': [{'offset': 4064, 'length': 17}], 'boundingRegions': [{'pageNumber': 3, 'polygon': [3.9653, 0.1014, 4.2695, 0.1014, 4.2695, 0.294, 3.9653, 0.294]}], 'role': 'title', 'content': 'PART ! Item 1\n==='},
#  {'spans': [{'offset': 4083, 'length': 80}], 'boundingRegions': [{'pageNumber': 3, 'polygon': [2.8945, 0.4314, 5.3288, 0.4254, 5.3302, 0.9873, 2.8959, 0.9932]}], 'role': 'title', 'content': 'PART I. FINANCIAL INFORMATION ITEM 1. FINANCIAL STATEMENTS INCOME STATEMENTS\n==='},
#  {'spans': [{'offset': 4167, 'length': 51}], 'boundingRegions': [{'pageNumber': 3, 'polygon': [0.1944, 1.0839, 3.3548, 1.0839, 3.3548, 1.3974, 0.1944, 1.3974]}], 'content': '(In millions, except per share amounts) (Unaudited)'},
#  {'spans': [{'offset': 4221, 'length': 56}], 'boundingRegions': [{'pageNumber': 3, 'polygon': [3.3548, 1.0839, 8.003, 1.0839, 8.003, 1.3974, 3.3548, 1.3974]}], 'content': 'Three Months Ended Nine Months Ended March 31, March 31,'},
#  {'spans': [{'offset': 4287, 'length': 4}], 'boundingRegions': [{'pageNumber': 3, 'polygon': [3.3548, 1.3974, 5.1562, 1.3974, 5.1562, 1.6145, 3.3548, 1.6225]}], 'content': '2023'},
#  {'spans': [{'offset': 4294, 'length': 4}], 'boundingRegions': [{'pageNumber': 3, 'polygon': [5.1562, 1.3974, 6.1212, 1.3974, 6.1212, 1.6145, 5.1562, 1.6145]}], 'content': '2022'},
#  {'spans': [{'offset': 4301, 'length': 4}], 'boundingRegions': [{'pageNumber': 3, 'polygon': [6.1212, 1.3974, 7.046, 1.3974, 7.046, 1.6145, 6.1212, 1.6145]}], 'content': '2023'},
#  {'spans': [{'offset': 4308, 'length': 4}], 'boundingRegions': [{'pageNumber': 3, 'polygon': [7.046, 1.3974, 8.003, 1.3974, 8.003, 1.6145, 7.046, 1.6145]}], 'content': '2022'},
#  {'spans': [{'offset': 4339, 'length': 8}], 'boundingRegions': [{'pageNumber': 3, 'polygon': [0.1944, 1.6225, 3.3548, 1.6225, 3.3548, 1.7833, 0.1944, 1.7833]}], 'content': 'Revenue:'},
#  {'spans': [{'offset': 4360, 'length': 7}], 'boundingRegions': [{'pageNumber': 3, 'polygon': [0.1944, 1.7833, 3.3548, 1.7833, 3.3548, 1.936, 0.1944, 1.936]}], 'content': 'Product'},
#  {'spans': [{'offset': 4370, 'length': 1}, {'offset': 4373, 'length': 6}], 'boundingRegions': [{'pageNumber': 3, 'polygon': [3.3548, 1.7833, 5.1562, 1.7833, 5.1562, 1.936, 3.3548, 1.936]}], 'content': '$\n15,588'},
#  {'spans': [{'offset': 4380, 'length': 1}, {'offset': 4384, 'length': 6}], 'boundingRegions': [{'pageNumber': 3, 'polygon': [5.1562, 1.7833, 6.1212, 1.7833, 6.1212, 1.936, 5.1562, 1.936]}], 'content': '$\n17,366'},
#  {'spans': [{'offset': 4391, 'length': 1}, {'offset': 4395, 'length': 6}], 'boundingRegions': [{'pageNumber': 3, 'polygon': [6.1212, 1.7833, 7.046, 1.7833, 7.046, 1.936, 6.1212, 1.936]}], 'content': '$\n47,846'},
#  {'spans': [{'offset': 4402, 'length': 1}, {'offset': 4405, 'length': 6}], 'boundingRegions': [{'pageNumber': 3, 'polygon': [7.046, 1.7833, 8.003, 1.7672, 8.003, 1.936, 7.046, 1.936]}], 'content': '$\n54,776'},
#  {'spans': [{'offset': 4416, 'length': 17}], 'boundingRegions': [{'pageNumber': 3, 'polygon': [0.1944, 1.936, 3.3548, 1.936, 3.3548, 2.153, 0.1944, 2.153]}], 'content': 'Service and other'},
#  {'spans': [{'offset': 4436, 'length': 6}], 'boundingRegions': [{'pageNumber': 3, 'polygon': [3.3548, 1.936, 5.1562, 1.936, 5.1562, 2.153, 3.3548, 2.153]}], 'content': '37,269'},
#  {'spans': [{'offset': 4445, 'length': 6}], 'boundingRegions': [{'pageNumber': 3, 'polygon': [5.1562, 1.936, 6.1212, 1.936, 6.1212, 2.153, 5.1562, 2.153]}], 'content': '31,994'},
#  {'spans': [{'offset': 4454, 'length': 7}], 'boundingRegions': [{'pageNumber': 3, 'polygon': [6.1212, 1.936, 7.046, 1.936, 7.046, 2.153, 6.1212, 2.153]}], 'content': '107,880'},
#  {'spans': [{'offset': 4464, 'length': 6}], 'boundingRegions': [{'pageNumber': 3, 'polygon': [7.046, 1.936, 8.003, 1.936, 8.003, 2.145, 7.046, 2.153]}], 'content': '91,629'},
#  {'spans': [{'offset': 4475, 'length': 13}], 'boundingRegions': [{'pageNumber': 3, 'polygon': [0.1944, 2.153, 3.3548, 2.153, 3.3548, 2.4263, 0.2024, 2.4263]}], 'content': 'Total revenue'},
#  {'spans': [{'offset': 4491, 'length': 6}], 'boundingRegions': [{'pageNumber': 3, 'polygon': [3.3548, 2.153, 5.1562, 2.153, 5.1562, 2.4263, 3.3548, 2.4263]}], 'content': '52,857'},
#  {'spans': [{'offset': 4500, 'length': 6}], 'boundingRegions': [{'pageNumber': 3, 'polygon': [5.1562, 2.153, 6.1212, 2.153, 6.1212, 2.4263, 5.1562, 2.4263]}], 'content': '49,360'},
#  {'spans': [{'offset': 4509, 'length': 7}], 'boundingRegions': [{'pageNumber': 3, 'polygon': [6.1212, 2.153, 7.046, 2.153, 7.046, 2.4263, 6.1212, 2.4263]}], 'content': '155,726'},
#  {'spans': [{'offset': 4519, 'length': 7}], 'boundingRegions': [{'pageNumber': 3, 'polygon': [7.046, 2.153, 8.003, 2.145, 8.011, 2.4263, 7.046, 2.4263]}], 'content': '146,405'},
#  {'spans': [{'offset': 4531, 'length': 16}], 'boundingRegions': [{'pageNumber': 3, 'polygon': [0.2024, 2.4263, 3.3548, 2.4263, 3.3548, 2.6273, 0.2024, 2.6273]}], 'content': 'Cost of revenue:'},
#  {'spans': [{'offset': 4560, 'length': 7}], 'boundingRegions': [{'pageNumber': 3, 'polygon': [0.2024, 2.6273, 3.3548, 2.6273, 3.3548, 2.7881, 0.2024, 2.78]}], 'content': 'Product'},
#  {'spans': [{'offset': 4570, 'length': 5}], 'boundingRegions': [{'pageNumber': 3, 'polygon': [3.3548, 2.6273, 5.1562, 2.6192, 5.1562, 2.78, 3.3548, 2.7881]}], 'content': '3,941'},
#  {'spans': [{'offset': 4578, 'length': 5}], 'boundingRegions': [{'pageNumber': 3, 'polygon': [5.1562, 2.6192, 6.1212, 2.6192, 6.1212, 2.78, 5.1562, 2.78]}], 'content': '4,584'},
#  {'spans': [{'offset': 4586, 'length': 6}], 'boundingRegions': [{'pageNumber': 3, 'polygon': [6.1212, 2.6192, 7.046, 2.6192, 7.046, 2.78, 6.1212, 2.78]}], 'content': '13,933'},
#  {'spans': [{'offset': 4595, 'length': 6}], 'boundingRegions': [{'pageNumber': 3, 'polygon': [7.046, 2.6192, 8.011, 2.6192, 8.011, 2.78, 7.046, 2.78]}], 'content': '14,707'},
#  {'spans': [{'offset': 4606, 'length': 17}], 'boundingRegions': [{'pageNumber': 3, 'polygon': [0.2024, 2.78, 3.3548, 2.7881, 3.3548, 2.997, 0.2024, 2.989]}], 'content': 'Service and other'},
#  {'spans': [{'offset': 4626, 'length': 6}], 'boundingRegions': [{'pageNumber': 3, 'polygon': [3.3548, 2.7881, 5.1562, 2.78, 5.1562, 2.997, 3.3548, 2.997]}], 'content': '12,187'},
#  {'spans': [{'offset': 4635, 'length': 6}], 'boundingRegions': [{'pageNumber': 3, 'polygon': [5.1562, 2.78, 6.1212, 2.78, 6.1212, 2.997, 5.1562, 2.997]}], 'content': '11,031'},
#  {'spans': [{'offset': 4644, 'length': 6}], 'boundingRegions': [{'pageNumber': 3, 'polygon': [6.1212, 2.78, 7.046, 2.78, 7.046, 2.997, 6.1212, 2.997]}], 'content': '35,135'},
#  {'spans': [{'offset': 4653, 'length': 6}], 'boundingRegions': [{'pageNumber': 3, 'polygon': [7.046, 2.78, 8.011, 2.78, 8.011, 2.981, 7.046, 2.997]}], 'content': '31,514'},
#  {'spans': [{'offset': 4664, 'length': 21}], 'boundingRegions': [{'pageNumber': 3, 'polygon': [0.2024, 2.989, 3.3548, 2.997, 3.3548, 3.2543, 0.2024, 3.2543]}], 'content': 'Total cost of revenue'},
#  {'spans': [{'offset': 4688, 'length': 6}], 'boundingRegions': [{'pageNumber': 3, 'polygon': [3.3548, 2.997, 5.1562, 2.997, 5.1562, 3.2543, 3.3548, 3.2543]}], 'content': '16,128'},
#  {'spans': [{'offset': 4697, 'length': 6}], 'boundingRegions': [{'pageNumber': 3, 'polygon': [5.1562, 2.997, 6.1212, 2.997, 6.1212, 3.2543, 5.1562, 3.2543]}], 'content': '15,615'},
#  {'spans': [{'offset': 4706, 'length': 6}], 'boundingRegions': [{'pageNumber': 3, 'polygon': [6.1212, 2.997, 7.046, 2.997, 7.046, 3.2543, 6.1212, 3.2543]}], 'content': '49,068'},
#  {'spans': [{'offset': 4715, 'length': 6}], 'boundingRegions': [{'pageNumber': 3, 'polygon': [7.046, 2.997, 8.011, 2.981, 8.011, 3.2543, 7.046, 3.2543]}], 'content': '46,221'},
#  {'spans': [{'offset': 4726, 'length': 12}], 'boundingRegions': [{'pageNumber': 3, 'polygon': [0.2024, 3.2543, 3.3548, 3.2543, 3.3548, 3.4633, 0.2024, 3.4633]}], 'content': 'Gross margin'},
#  {'spans': [{'offset': 4741, 'length': 6}], 'boundingRegions': [{'pageNumber': 3, 'polygon': [3.3548, 3.2543, 5.1562, 3.2543, 5.1562, 3.4633, 3.3548, 3.4633]}], 'content': '36,729'},
#  {'spans': [{'offset': 4750, 'length': 6}], 'boundingRegions': [{'pageNumber': 3, 'polygon': [5.1562, 3.2543, 6.1212, 3.2543, 6.1212, 3.4633, 5.1562, 3.4633]}], 'content': '33,745'},
#  {'spans': [{'offset': 4759, 'length': 7}], 'boundingRegions': [{'pageNumber': 3, 'polygon': [6.1212, 3.2543, 7.046, 3.2543, 7.046, 3.4552, 6.1212, 3.4633]}], 'content': '106,658'},
#  {'spans': [{'offset': 4769, 'length': 7}], 'boundingRegions': [{'pageNumber': 3, 'polygon': [7.046, 3.2543, 8.011, 3.2543, 8.011, 3.4552, 7.046, 3.4552]}], 'content': '100,184'},
#  {'spans': [{'offset': 4781, 'length': 24}], 'boundingRegions': [{'pageNumber': 3, 'polygon': [0.2024, 3.4633, 3.3548, 3.4633, 3.3548, 3.624, 0.2024, 3.624]}], 'content': 'Research and development'},
#  {'spans': [{'offset': 4808, 'length': 5}], 'boundingRegions': [{'pageNumber': 3, 'polygon': [3.3548, 3.4633, 5.1562, 3.4633, 5.1562, 3.624, 3.3548, 3.624]}], 'content': '6,984'},
#  {'spans': [{'offset': 4816, 'length': 5}], 'boundingRegions': [{'pageNumber': 3, 'polygon': [5.1562, 3.4633, 6.1212, 3.4633, 6.1212, 3.624, 5.1562, 3.624]}], 'content': '6,306'},
#  {'spans': [{'offset': 4824, 'length': 6}], 'boundingRegions': [{'pageNumber': 3, 'polygon': [6.1212, 3.4633, 7.046, 3.4552, 7.046, 3.616, 6.1212, 3.624]}], 'content': '20,456'},
#  {'spans': [{'offset': 4833, 'length': 6}], 'boundingRegions': [{'pageNumber': 3, 'polygon': [7.046, 3.4552, 8.011, 3.4552, 8.011, 3.616, 7.046, 3.616]}], 'content': '17,663'},
#  {'spans': [{'offset': 4844, 'length': 19}], 'boundingRegions': [{'pageNumber': 3, 'polygon': [0.2024, 3.624, 3.3548, 3.624, 3.3548, 3.7928, 0.2024, 3.7768]}], 'content': 'Sales and marketing'},
#  {'spans': [{'offset': 4866, 'length': 5}], 'boundingRegions': [{'pageNumber': 3, 'polygon': [3.3548, 3.624, 5.1562, 3.624, 5.1562, 3.7928, 3.3548, 3.7928]}], 'content': '5,750'},
#  {'spans': [{'offset': 4874, 'length': 5}], 'boundingRegions': [{'pageNumber': 3, 'polygon': [5.1562, 3.624, 6.1212, 3.624, 6.1212, 3.7928, 5.1562, 3.7928]}], 'content': '5,595'},
#  {'spans': [{'offset': 4882, 'length': 6}], 'boundingRegions': [{'pageNumber': 3, 'polygon': [6.1212, 3.624, 7.046, 3.616, 7.046, 3.7928, 6.1212, 3.7928]}], 'content': '16,555'},
#  {'spans': [{'offset': 4891, 'length': 6}], 'boundingRegions': [{'pageNumber': 3, 'polygon': [7.046, 3.616, 8.011, 3.616, 8.011, 3.7768, 7.046, 3.7928]}], 'content': '15,521'},
#  {'spans': [{'offset': 4902, 'length': 26}], 'boundingRegions': [{'pageNumber': 3, 'polygon': [0.2024, 3.7768, 3.3548, 3.7928, 3.3548, 3.9938, 0.2024, 3.9938]}], 'content': 'General and administrative'},
#  {'spans': [{'offset': 4931, 'length': 5}], 'boundingRegions': [{'pageNumber': 3, 'polygon': [3.3548, 3.7928, 5.1562, 3.7928, 5.1562, 3.9938, 3.3548, 3.9938]}], 'content': '1,643'},
#  {'spans': [{'offset': 4939, 'length': 5}], 'boundingRegions': [{'pageNumber': 3, 'polygon': [5.1562, 3.7928, 6.1212, 3.7928, 6.1212, 3.9938, 5.1562, 3.9938]}], 'content': '1,480'},
#  {'spans': [{'offset': 4947, 'length': 5}], 'boundingRegions': [{'pageNumber': 3, 'polygon': [6.1212, 3.7928, 7.046, 3.7928, 7.046, 3.9938, 6.1212, 3.9938]}], 'content': '5,378'},
#  {'spans': [{'offset': 4955, 'length': 5}], 'boundingRegions': [{'pageNumber': 3, 'polygon': [7.046, 3.7928, 8.011, 3.7768, 8.011, 3.9938, 7.046, 3.9938]}], 'content': '4,151'},
#  {'spans': [{'offset': 4965, 'length': 16}], 'boundingRegions': [{'pageNumber': 3, 'polygon': [0.2024, 3.9938, 3.3548, 3.9938, 3.3548, 4.2108, 0.2024, 4.2108]}], 'content': 'Operating income'},
#  {'spans': [{'offset': 4984, 'length': 6}], 'boundingRegions': [{'pageNumber': 3, 'polygon': [3.3548, 3.9938, 5.1562, 3.9938, 5.1562, 4.2108, 3.3548, 4.2108]}], 'content': '22,352'},
#  {'spans': [{'offset': 4993, 'length': 6}], 'boundingRegions': [{'pageNumber': 3, 'polygon': [5.1562, 3.9938, 6.1212, 3.9938, 6.1212, 4.2108, 5.1562, 4.2108]}], 'content': '20,364'},
#  {'spans': [{'offset': 5002, 'length': 6}], 'boundingRegions': [{'pageNumber': 3, 'polygon': [6.1212, 3.9938, 7.046, 3.9938, 7.046, 4.2108, 6.1212, 4.2108]}], 'content': '64,269'},
#  {'spans': [{'offset': 5011, 'length': 6}], 'boundingRegions': [{'pageNumber': 3, 'polygon': [7.046, 3.9938, 8.011, 3.9938, 8.011, 4.2108, 7.046, 4.2108]}], 'content': '62,849'},
#  {'spans': [{'offset': 5022, 'length': 27}], 'boundingRegions': [{'pageNumber': 3, 'polygon': [0.2024, 4.2108, 3.3548, 4.2108, 3.3548, 4.4118, 0.2024, 4.4118]}], 'content': 'Other income (expense), net'},
#  {'spans': [{'offset': 5052, 'length': 3}], 'boundingRegions': [{'pageNumber': 3, 'polygon': [3.3548, 4.2108, 5.1562, 4.2108, 5.1562, 4.4118, 3.3548, 4.4118]}], 'content': '321'},
#  {'spans': [{'offset': 5058, 'length': 5}], 'boundingRegions': [{'pageNumber': 3, 'polygon': [5.1562, 4.2108, 6.1212, 4.2108, 6.1212, 4.4118, 5.1562, 4.4118]}], 'content': '(174)'},
#  {'spans': [{'offset': 5066, 'length': 3}], 'boundingRegions': [{'pageNumber': 3, 'polygon': [6.1212, 4.2108, 7.046, 4.2108, 7.046, 4.4118, 6.1212, 4.4118]}], 'content': '315'},
#  {'spans': [{'offset': 5072, 'length': 3}], 'boundingRegions': [{'pageNumber': 3, 'polygon': [7.046, 4.2108, 8.011, 4.2108, 8.011, 4.4118, 7.046, 4.4118]}], 'content': '380'},
#  {'spans': [{'offset': 5080, 'length': 26}], 'boundingRegions': [{'pageNumber': 3, 'polygon': [0.2024, 4.4118, 3.3548, 4.4118, 3.3548, 4.6288, 0.2024, 4.6208]}], 'content': 'Income before income taxes'},
#  {'spans': [{'offset': 5109, 'length': 6}], 'boundingRegions': [{'pageNumber': 3, 'polygon': [3.3548, 4.4118, 5.1562, 4.4118, 5.1562, 4.6288, 3.3548, 4.6288]}], 'content': '22,673'},
#  {'spans': [{'offset': 5118, 'length': 6}], 'boundingRegions': [{'pageNumber': 3, 'polygon': [5.1562, 4.4118, 6.1212, 4.4118, 6.1212, 4.6288, 5.1562, 4.6288]}], 'content': '20,190'},
#  {'spans': [{'offset': 5127, 'length': 6}], 'boundingRegions': [{'pageNumber': 3, 'polygon': [6.1212, 4.4118, 7.046, 4.4118, 7.046, 4.6288, 6.1212, 4.6288]}], 'content': '64,584'},
#  {'spans': [{'offset': 5136, 'length': 6}], 'boundingRegions': [{'pageNumber': 3, 'polygon': [7.046, 4.4118, 8.011, 4.4118, 8.011, 4.6288, 7.046, 4.6288]}], 'content': '63,229'},
#  {'spans': [{'offset': 5147, 'length': 26}], 'boundingRegions': [{'pageNumber': 3, 'polygon': [0.2024, 4.6208, 3.3548, 4.6288, 3.3548, 4.8378, 0.2024, 4.8378]}], 'content': 'Provision for income taxes'},
#  {'spans': [{'offset': 5176, 'length': 5}], 'boundingRegions': [{'pageNumber': 3, 'polygon': [3.3548, 4.6288, 5.1562, 4.6288, 5.1562, 4.8378, 3.3548, 4.8378]}], 'content': '4,374'},
#  {'spans': [{'offset': 5184, 'length': 5}], 'boundingRegions': [{'pageNumber': 3, 'polygon': [5.1562, 4.6288, 6.1212, 4.6288, 6.1212, 4.8378, 5.1562, 4.8378]}], 'content': '3,462'},
#  {'spans': [{'offset': 5192, 'length': 6}], 'boundingRegions': [{'pageNumber': 3, 'polygon': [6.1212, 4.6288, 7.046, 4.6288, 7.046, 4.8378, 6.1212, 4.8378]}], 'content': '12,304'},
#  {'spans': [{'offset': 5201, 'length': 5}], 'boundingRegions': [{'pageNumber': 3, 'polygon': [7.046, 4.6288, 8.011, 4.6288, 8.011, 4.8378, 7.046, 4.8378]}], 'content': '7,231'},
#  {'spans': [{'offset': 5211, 'length': 10}], 'boundingRegions': [{'pageNumber': 3, 'polygon': [0.2024, 4.8378, 3.3548, 4.8378, 3.3548, 5.0789, 0.2024, 5.0789]}], 'content': 'Net income'},
#  {'spans': [{'offset': 5224, 'length': 8}], 'boundingRegions': [{'pageNumber': 3, 'polygon': [3.3548, 4.8378, 5.1562, 4.8378, 5.1562, 5.0789, 3.3548, 5.0789]}], 'content': '$ 18,299'},
#  {'spans': [{'offset': 5235, 'length': 1}, {'offset': 5238, 'length': 6}], 'boundingRegions': [{'pageNumber': 3, 'polygon': [5.1562, 4.8378, 6.1212, 4.8378, 6.1212, 5.0789, 5.1562, 5.0789]}], 'content': '$\n16,728'},
# ...
#  {'spans': [{'offset': 28579, 'length': 1}, {'offset': 28582, 'length': 5}], 'boundingRegions': [{'pageNumber': 13, 'polygon': [4.8285, 4.5223, 5.5915, 4.5223, 5.5915, 4.699, 4.8285, 4.699]}], 'content': '$\n3,475'},
#  {'spans': [{'offset': 28588, 'length': 1}, {'offset': 28592, 'length': 3}], 'boundingRegions': [{'pageNumber': 13, 'polygon': [5.5915, 4.5223, 6.3706, 4.5223, 6.3706, 4.699, 5.5915, 4.699]}], 'content': '$\n979'},
#  {'spans': [{'offset': 28596, 'length': 1}, {'offset': 28600, 'length': 1}], 'boundingRegions': [{'pageNumber': 13, 'polygon': [6.3706, 4.5223, 7.1738, 4.5223, 7.1738, 4.699, 6.3706, 4.699]}], 'content': '$\n0'},
#  {'spans': [{'offset': 28602, 'length': 1}, {'offset': 28605, 'length': 5}], 'boundingRegions': [{'pageNumber': 13, 'polygon': [7.1738, 4.5223, 7.993, 4.5223, 7.993, 4.699, 7.1738, 4.699]}], 'content': '$\n2,496'},
#  {'spans': [{'offset': 28615, 'length': 18}], 'boundingRegions': [{'pageNumber': 13, 'polygon': [0.1941, 4.6829, 1.9049, 4.699, 1.9049, 4.8997, 0.1941, 4.8997]}], 'content': 'Equity investments'},
#  {'spans': [{'offset': 28636, 'length': 5}], 'boundingRegions': [{'pageNumber': 13, 'polygon': [1.9049, 4.699, 2.5072, 4.699, 2.5072, 4.8997, 1.9049, 4.8997]}], 'content': 'Other'},
#  {'spans': [{'offset': 28650, 'length': 5}], 'boundingRegions': [{'pageNumber': 13, 'polygon': [4.8285, 4.699, 5.5915, 4.699, 5.5915, 4.8997, 4.8285, 4.8997]}], 'content': '6,919'},
#  {'spans': [{'offset': 28658, 'length': 1}], 'boundingRegions': [{'pageNumber': 13, 'polygon': [5.5915, 4.699, 6.3706, 4.699, 6.3706, 4.9077, 5.5915, 4.8997]}], 'content': '0'},
#  {'spans': [{'offset': 28662, 'length': 1}], 'boundingRegions': [{'pageNumber': 13, 'polygon': [6.3706, 4.699, 7.1738, 4.699, 7.1738, 4.9077, 6.3706, 4.9077]}], 'content': '0'},
#  {'spans': [{'offset': 28666, 'length': 5}], 'boundingRegions': [{'pageNumber': 13, 'polygon': [7.1738, 4.699, 7.993, 4.699, 8.001, 4.9077, 7.1738, 4.9077]}], 'content': '6,919'},
#  {'spans': [{'offset': 28676, 'length': 24}], 'boundingRegions': [{'pageNumber': 13, 'polygon': [0.1941, 4.8997, 1.9049, 4.8997, 1.9049, 5.1485, 0.186, 5.1485]}], 'content': 'Total equity investments'},
#  {'spans': [{'offset': 28711, 'length': 1}, {'offset': 28714, 'length': 6}], 'boundingRegions': [{'pageNumber': 13, 'polygon': [4.8285, 4.8997, 5.5915, 4.8997, 5.5915, 5.1485, 4.8285, 5.1485]}], 'content': '$\n10,394'},
#  {'spans': [{'offset': 28721, 'length': 1}, {'offset': 28724, 'length': 3}], 'boundingRegions': [{'pageNumber': 13, 'polygon': [5.5915, 4.8997, 6.3706, 4.9077, 6.3706, 5.1485, 5.5915, 5.1485]}], 'content': '$\n979'},
#  {'spans': [{'offset': 28730, 'length': 3}], 'boundingRegions': [{'pageNumber': 13, 'polygon': [6.3706, 4.9077, 7.1738, 4.9077, 7.1738, 5.1485, 6.3706, 5.1485]}], 'content': '$ 0'},
#  {'spans': [{'offset': 28736, 'length': 7}], 'boundingRegions': [{'pageNumber': 13, 'polygon': [7.1738, 4.9077, 8.001, 4.9077, 8.001, 5.1405, 7.1738, 5.1485]}], 'content': '$ 9,415'},
#  {'spans': [{'offset': 28748, 'length': 4}], 'boundingRegions': [{'pageNumber': 13, 'polygon': [0.186, 5.1485, 1.9049, 5.1485, 1.9049, 5.3894, 0.186, 5.3733]}], 'content': 'Cash'},
#  {'spans': [{'offset': 28763, 'length': 7}], 'boundingRegions': [{'pageNumber': 13, 'polygon': [4.8285, 5.1485, 5.5915, 5.1485, 5.5915, 5.3894, 4.8285, 5.3894]}], 'content': '$ 8,509'},
#  {'spans': [{'offset': 28773, 'length': 7}], 'boundingRegions': [{'pageNumber': 13, 'polygon': [5.5915, 5.1485, 6.3706, 5.1485, 6.3706, 5.3894, 5.5915, 5.3894]}], 'content': '$ 8,509'},
#  {'spans': [{'offset': 28783, 'length': 3}], 'boundingRegions': [{'pageNumber': 13, 'polygon': [6.3706, 5.1485, 7.1738, 5.1485, 7.1738, 5.3894, 6.3706, 5.3894]}], 'content': '$ 0'},
#  {'spans': [{'offset': 28789, 'length': 3}], 'boundingRegions': [{'pageNumber': 13, 'polygon': [7.1738, 5.1485, 8.001, 5.1405, 8.001, 5.3894, 7.1738, 5.3894]}], 'content': '$ 0'},
#  {'spans': [{'offset': 28797, 'length': 20}], 'boundingRegions': [{'pageNumber': 13, 'polygon': [0.186, 5.3733, 1.9049, 5.3894, 1.9049, 5.5901, 0.186, 5.5901]}], 'content': 'Derivatives, net (a)'},
#  {'spans': [{'offset': 28828, 'length': 1}], 'boundingRegions': [{'pageNumber': 13, 'polygon': [4.8285, 5.3894, 5.5915, 5.3894, 5.5915, 5.5981, 4.8285, 5.5901]}], 'content': '8'},
#  {'spans': [{'offset': 28832, 'length': 1}], 'boundingRegions': [{'pageNumber': 13, 'polygon': [5.5915, 5.3894, 6.3706, 5.3894, 6.3706, 5.5981, 5.5915, 5.5981]}], 'content': '0'},
#  {'spans': [{'offset': 28836, 'length': 1}], 'boundingRegions': [{'pageNumber': 13, 'polygon': [6.3706, 5.3894, 7.1738, 5.3894, 7.1738, 5.5981, 6.3706, 5.5981]}], 'content': '8'},
#  {'spans': [{'offset': 28840, 'length': 1}], 'boundingRegions': [{'pageNumber': 13, 'polygon': [7.1738, 5.3894, 8.001, 5.3894, 8.001, 5.5981, 7.1738, 5.5981]}], 'content': '0'},
#  {'spans': [{'offset': 28846, 'length': 5}], 'boundingRegions': [{'pageNumber': 13, 'polygon': [0.186, 5.5901, 1.9049, 5.5901, 1.9049, 5.8791, 0.186, 5.8631]}], 'content': 'Total'},
#  {'spans': [{'offset': 28862, 'length': 9}], 'boundingRegions': [{'pageNumber': 13, 'polygon': [4.8285, 5.5901, 5.5915, 5.5981, 5.5915, 5.8791, 4.8285, 5.8791]}], 'content': '$ 113,842'},
#  {'spans': [{'offset': 28874, 'length': 8}], 'boundingRegions': [{'pageNumber': 13, 'polygon': [5.5915, 5.5981, 6.3706, 5.5981, 6.3706, 5.8872, 5.5915, 5.8791]}], 'content': '$ 26,562'},
#  {'spans': [{'offset': 28885, 'length': 8}], 'boundingRegions': [{'pageNumber': 13, 'polygon': [6.3706, 5.5981, 7.1738, 5.5981, 7.1738, 5.8791, 6.3706, 5.8872]}], 'content': '$ 77,865'},
#  {'spans': [{'offset': 28896, 'length': 7}], 'boundingRegions': [{'pageNumber': 13, 'polygon': [7.1738, 5.5981, 8.001, 5.5981, 8.001, 5.8711, 7.1738, 5.8791]}], 'content': '$ 9,415'},
#  {'spans': [{'offset': 28907, 'length': 24}], 'boundingRegions': [{'pageNumber': 13, 'polygon': [4.0515, 6.1799, 4.1782, 6.1799, 4.1782, 6.2763, 4.0515, 6.2763]}], 'role': 'pageNumber', 'content': '<!-- PageNumber="13" -->'},
#  {'spans': [{'offset': 28933, 'length': 13}], 'boundingRegions': [{'pageNumber': 14, 'polygon': [3.9653, 0.1014, 4.2797, 0.1014, 4.2797, 0.2991, 3.9653, 0.2991]}], 'content': 'PART ! Item 1'},
#  {'spans': [{'offset': 28950, 'length': 13}], 'boundingRegions': [{'pageNumber': 14, 'polygon': [0.2101, 0.3942, 1.9129, 0.3942, 1.9129, 0.8038, 0.2101, 0.8038]}], 'content': '(In millions)'},
#  {'spans': [{'offset': 28966, 'length': 16}], 'boundingRegions': [{'pageNumber': 14, 'polygon': [1.9129, 0.3942, 2.4992, 0.3942, 2.4992, 0.8038, 1.9129, 0.8038]}], 'content': 'Fair Value Level'},
#  {'spans': [{'offset': 28985, 'length': 19}], 'boundingRegions': [{'pageNumber': 14, 'polygon': [2.4992, 0.3942, 3.3426, 0.3942, 3.3426, 0.8038, 2.4992, 0.8038]}], 'content': 'Adjusted Cost Basis'},
#  {'spans': [{'offset': 29007, 'length': 16}], 'boundingRegions': [{'pageNumber': 14, 'polygon': [3.3426, 0.3942, 4.1136, 0.3942, 4.1136, 0.8118, 3.3426, 0.8038]}], 'content': 'Unrealized Gains'},
#  {'spans': [{'offset': 29026, 'length': 17}], 'boundingRegions': [{'pageNumber': 14, 'polygon': [4.1136, 0.3942, 4.9329, 0.3942, 4.9329, 0.8118, 4.1136, 0.8118]}], 'content': 'Unrealized Losses'},
#  {'spans': [{'offset': 29046, 'length': 14}], 'boundingRegions': [{'pageNumber': 14, 'polygon': [4.9329, 0.3942, 5.6879, 0.3942, 5.6879, 0.8118, 4.9329, 0.8118]}], 'content': 'Recorded Basis'},
#  {'spans': [{'offset': 29063, 'length': 25}], 'boundingRegions': [{'pageNumber': 14, 'polygon': [5.6879, 0.3942, 6.4268, 0.3942, 6.4268, 0.8118, 5.6879, 0.8118]}], 'content': 'Cash and Cash Equivalents'},
#  {'spans': [{'offset': 29091, 'length': 22}], 'boundingRegions': [{'pageNumber': 14, 'polygon': [6.4268, 0.3942, 7.1979, 0.3942, 7.1979, 0.8118, 6.4268, 0.8118]}], 'content': 'Short-term Investments'},
#  {'spans': [{'offset': 29116, 'length': 18}], 'boundingRegions': [{'pageNumber': 14, 'polygon': [7.1979, 0.3942, 7.993, 0.3942, 7.993, 0.8118, 7.1979, 0.8118]}], 'content': 'Equity Investments'},
#  {'spans': [{'offset': 29177, 'length': 13}], 'boundingRegions': [{'pageNumber': 14, 'polygon': [0.2101, 0.8038, 1.9129, 0.8038, 1.9129, 1.0125, 0.2101, 1.0125]}], 'content': 'June 30, 2022'},
#  {'spans': [{'offset': 29211, 'length': 60}], 'boundingRegions': [{'pageNumber': 14, 'polygon': [0.2101, 1.0125, 1.9129, 1.0125, 1.9129, 1.2936, 0.2101, 1.2936]}], 'content': 'Changes in Fair Value Recorded in Other Comprehensive Income'},
#  {'spans': [{'offset': 29292, 'length': 16}], 'boundingRegions': [{'pageNumber': 14, 'polygon': [0.2101, 1.2936, 1.9129, 1.2936, 1.9129, 1.4542, 0.2101, 1.4542]}], 'content': 'Commercial paper'},
#  {'spans': [{'offset': 29311, 'length': 7}], 'boundingRegions': [{'pageNumber': 14, 'polygon': [1.9129, 1.2936, 2.4992, 1.2936, 2.4992, 1.4542, 1.9129, 1.4542]}], 'content': 'Level 2'},
#  {'spans': [{'offset': 29321, 'length': 1}, {'offset': 29324, 'length': 5}], 'boundingRegions': [{'pageNumber': 14, 'polygon': [2.4992, 1.2936, 3.3426, 1.2936, 3.3426, 1.4542, 2.4992, 1.4542]}], 'content': '$\n2,500'},
#  {'spans': [{'offset': 29330, 'length': 1}, {'offset': 29334, 'length': 1}], 'boundingRegions': [{'pageNumber': 14, 'polygon': [3.3426, 1.2936, 4.1136, 1.2936, 4.1136, 1.4542, 3.3426, 1.4542]}], 'content': '$\n0'},
#  {'spans': [{'offset': 29336, 'length': 1}, {'offset': 29339, 'length': 1}], 'boundingRegions': [{'pageNumber': 14, 'polygon': [4.1136, 1.2936, 4.9329, 1.2936, 4.9329, 1.4542, 4.1136, 1.4542]}], 'content': '$\n0'},
#  {'spans': [{'offset': 29343, 'length': 1}, {'offset': 29346, 'length': 5}], 'boundingRegions': [{'pageNumber': 14, 'polygon': [4.9329, 1.2936, 5.6879, 1.2936, 5.6879, 1.4542, 4.9329, 1.4542]}], 'content': '$\n2,500'},
#  {'spans': [{'offset': 29352, 'length': 1}, {'offset': 29356, 'length': 5}], 'boundingRegions': [{'pageNumber': 14, 'polygon': [5.6879, 1.2936, 6.4268, 1.2936, 6.4268, 1.4542, 5.6879, 1.4542]}], 'content': '$\n2,498'},
#  {'spans': [{'offset': 29362, 'length': 1}, {'offset': 29366, 'length': 1}], 'boundingRegions': [{'pageNumber': 14, 'polygon': [6.4268, 1.2936, 7.1979, 1.2936, 7.1979, 1.4622, 6.4268, 1.4542]}], 'content': '$\n2'},
#  {'spans': [{'offset': 29368, 'length': 1}, {'offset': 29371, 'length': 1}], 'boundingRegions': [{'pageNumber': 14, 'polygon': [7.1979, 1.2936, 7.993, 1.3016, 7.993, 1.4622, 7.1979, 1.4622]}], 'content': '$\n0'},
#  {'spans': [{'offset': 29377, 'length': 23}], 'boundingRegions': [{'pageNumber': 14, 'polygon': [0.2101, 1.4542, 1.9129, 1.4542, 1.9129, 1.6148, 0.2101, 1.6148]}], 'content': 'Certificates of deposit'},
#  {'spans': [{'offset': 29403, 'length': 7}], 'boundingRegions': [{'pageNumber': 14, 'polygon': [1.9129, 1.4542, 2.4992, 1.4542, 2.5072, 1.6148, 1.9129, 1.6148]}], 'content': 'Level 2'},
#  {'spans': [{'offset': 29413, 'length': 5}], 'boundingRegions': [{'pageNumber': 14, 'polygon': [2.4992, 1.4542, 3.3426, 1.4542, 3.3426, 1.6148, 2.5072, 1.6148]}], 'content': '2,071'},
#  {'spans': [{'offset': 29421, 'length': 1}], 'boundingRegions': [{'pageNumber': 14, 'polygon': [3.3426, 1.4542, 4.1136, 1.4542, 4.1136, 1.6148, 3.3426, 1.6148]}], 'content': '0'},
#  {'spans': [{'offset': 29425, 'length': 1}], 'boundingRegions': [{'pageNumber': 14, 'polygon': [4.1136, 1.4542, 4.9329, 1.4542, 4.9329, 1.6148, 4.1136, 1.6148]}], 'content': '0'},
#  {'spans': [{'offset': 29429, 'length': 5}], 'boundingRegions': [{'pageNumber': 14, 'polygon': [4.9329, 1.4542, 5.6879, 1.4542, 5.6798, 1.6148, 4.9329, 1.6148]}], 'content': '2,071'},
#  {'spans': [{'offset': 29437, 'length': 5}], 'boundingRegions': [{'pageNumber': 14, 'polygon': [5.6879, 1.4542, 6.4268, 1.4542, 6.4188, 1.6148, 5.6798, 1.6148]}], 'content': '2,032'},
#  {'spans': [{'offset': 29445, 'length': 2}], 'boundingRegions': [{'pageNumber': 14, 'polygon': [6.4268, 1.4542, 7.1979, 1.4622, 7.1979, 1.6148, 6.4188, 1.6148]}], 'content': '39'},
#  {'spans': [{'offset': 29450, 'length': 1}], 'boundingRegions': [{'pageNumber': 14, 'polygon': [7.1979, 1.4622, 7.993, 1.4622, 7.993, 1.6148, 7.1979, 1.6148]}], 'content': '0'},
#  {'spans': [{'offset': 29456, 'length': 26}], 'boundingRegions': [{'pageNumber': 14, 'polygon': [0.2101, 1.6148, 1.9129, 1.6148, 1.9129, 1.7754, 0.2101, 1.7754]}], 'content': 'U.S. government securities'},
#  {'spans': [{'offset': 29485, 'length': 7}], 'boundingRegions': [{'pageNumber': 14, 'polygon': [1.9129, 1.6148, 2.5072, 1.6148, 2.5072, 1.7754, 1.9129, 1.7754]}], 'content': 'Level 1'},
#  {'spans': [{'offset': 29495, 'length': 6}], 'boundingRegions': [{'pageNumber': 14, 'polygon': [2.5072, 1.6148, 3.3426, 1.6148, 3.3426, 1.7754, 2.5072, 1.7754]}], 'content': '79,696'},
#  {'spans': [{'offset': 29504, 'length': 2}], 'boundingRegions': [{'pageNumber': 14, 'polygon': [3.3426, 1.6148, 4.1136, 1.6148, 4.1136, 1.7754, 3.3426, 1.7754]}], 'content': '29'},
#  {'spans': [{'offset': 29509, 'length': 7}], 'boundingRegions': [{'pageNumber': 14, 'polygon': [4.1136, 1.6148, 4.9329, 1.6148, 4.9329, 1.7754, 4.1136, 1.7754]}], 'content': '(2,178)'},
#  {'spans': [{'offset': 29519, 'length': 6}], 'boundingRegions': [{'pageNumber': 14, 'polygon': [4.9329, 1.6148, 5.6798, 1.6148, 5.6798, 1.7754, 4.9329, 1.7754]}], 'content': '77,547'},
#  {'spans': [{'offset': 29528, 'length': 1}], 'boundingRegions': [{'pageNumber': 14, 'polygon': [5.6798, 1.6148, 6.4188, 1.6148, 6.4188, 1.7834, 5.6798, 1.7754]}], 'content': '9'},
#  {'spans': [{'offset': 29532, 'length': 6}], 'boundingRegions': [{'pageNumber': 14, 'polygon': [6.4188, 1.6148, 7.1979, 1.6148, 7.1979, 1.7834, 6.4188, 1.7834]}], 'content': '77,538'},
#  {'spans': [{'offset': 29541, 'length': 1}], 'boundingRegions': [{'pageNumber': 14, 'polygon': [7.1979, 1.6148, 7.993, 1.6148, 7.993, 1.7834, 7.1979, 1.7834]}], 'content': '0'},
#  {'spans': [{'offset': 29547, 'length': 22}], 'boundingRegions': [{'pageNumber': 14, 'polygon': [0.2101, 1.7754, 1.9129, 1.7754, 1.9129, 1.944, 0.2101, 1.9279]}], 'content': 'U.S. agency securities'},
#  {'spans': [{'offset': 29572, 'length': 7}], 'boundingRegions': [{'pageNumber': 14, 'polygon': [1.9129, 1.7754, 2.5072, 1.7754, 2.5072, 1.944, 1.9129, 1.944]}], 'content': 'Level 2'},
#  {'spans': [{'offset': 29582, 'length': 3}], 'boundingRegions': [{'pageNumber': 14, 'polygon': [2.5072, 1.7754, 3.3426, 1.7754, 3.3426, 1.944, 2.5072, 1.944]}], 'content': '419'},
#  {'spans': [{'offset': 29588, 'length': 1}], 'boundingRegions': [{'pageNumber': 14, 'polygon': [3.3426, 1.7754, 4.1136, 1.7754, 4.1136, 1.944, 3.3426, 1.944]}], 'content': '0'},
#  {'spans': [{'offset': 29592, 'length': 3}], 'boundingRegions': [{'pageNumber': 14, 'polygon': [4.1136, 1.7754, 4.9329, 1.7754, 4.9329, 1.944, 4.1136, 1.944]}], 'content': '(9)'},
#  {'spans': [{'offset': 29598, 'length': 3}], 'boundingRegions': [{'pageNumber': 14, 'polygon': [4.9329, 1.7754, 5.6798, 1.7754, 5.6798, 1.944, 4.9329, 1.944]}], 'content': '410'},
#  {'spans': [{'offset': 29604, 'length': 1}], 'boundingRegions': [{'pageNumber': 14, 'polygon': [5.6798, 1.7754, 6.4188, 1.7834, 6.4188, 1.944, 5.6798, 1.944]}], 'content': '0'},
#  {'spans': [{'offset': 29608, 'length': 3}], 'boundingRegions': [{'pageNumber': 14, 'polygon': [6.4188, 1.7834, 7.1979, 1.7834, 7.1979, 1.944, 6.4188, 1.944]}], 'content': '410'},
#  {'spans': [{'offset': 29614, 'length': 1}], 'boundingRegions': [{'pageNumber': 14, 'polygon': [7.1979, 1.7834, 7.993, 1.7834, 7.993, 1.944, 7.1979, 1.944]}], 'content': '0'},
#  {'spans': [{'offset': 29620, 'length': 24}], 'boundingRegions': [{'pageNumber': 14, 'polygon': [0.2101, 1.9279, 1.9129, 1.944, 1.9129, 2.1046, 0.2101, 2.0885]}], 'content': 'Foreign government bonds'},
#  {'spans': [{'offset': 29647, 'length': 7}], 'boundingRegions': [{'pageNumber': 14, 'polygon': [1.9129, 1.944, 2.5072, 1.944, 2.5072, 2.1046, 1.9129, 2.1046]}], 'content': 'Level 2'},
#  {'spans': [{'offset': 29657, 'length': 3}], 'boundingRegions': [{'pageNumber': 14, 'polygon': [2.5072, 1.944, 3.3426, 1.944, 3.3426, 2.1046, 2.5072, 2.1046]}], 'content': '506'},
#  {'spans': [{'offset': 29663, 'length': 1}], 'boundingRegions': [{'pageNumber': 14, 'polygon': [3.3426, 1.944, 4.1136, 1.944, 4.1136, 2.1046, 3.3426, 2.1046]}], 'content': '0'},
#  ...]

# %%
doc_string = result.content
strings_to_replace = re.findall(".+\n===", doc_string)
for string in strings_to_replace:
    doc_string = doc_string.replace(string, "=== "+string.replace("===",""))

## Split the document into chunks base on markdown headers.
headers_to_split_on = [
    ("===", "Title"),
    ("#", "Header 1"),
    ("##", "Header 2"),
    ("###", "Header 3"),
]
text_splitter = MarkdownHeaderTextSplitter(headers_to_split_on=headers_to_split_on)

markdown_chunks = text_splitter.split_text(doc_string)

# %%
chunk_list = []
for chunk in markdown_chunks:
    try:
        title = chunk.metadata['Title']
    except:
        title = ""
    try:
        header1 = chunk.metadata['Header 1']
    except:
        header1 = ""
    try:
        header2 = chunk.metadata['Header 2']
    except:
        header2 = ""
    try:
        header3 = chunk.metadata['Header 3']
    except:
        header3 = ""
    chunk_list.append({"title": title,"header1":header1,"header2":header2,"header3":header3,"content":chunk.page_content})

df = pd.DataFrame(chunk_list)

# %%
import tiktoken
encoding = tiktoken.get_encoding("cl100k_base")

def num_tokens_from_string(string: str) -> int:
    """Returns the number of tokens in a text string."""
    encoding = tiktoken.get_encoding("cl100k_base")
    num_tokens = len(encoding.encode(string))
    return num_tokens

# %%
df['token_length']=[num_tokens_from_string(chunk) for chunk in df.content]

# %%
df['full_text'] =" title: " + df['title'].astype(str) + " header1: " + +df['header1'].astype(str) + " header2: " +df['header2'].astype(str) +  " header3: " + df['header3'].astype(str) + " content: " + df['content'].astype(str)
df['full_title'] =" title: " + df['title'].astype(str) + " header1: " + +df['header1'].astype(str) + " header2: " +df['header2'].astype(str) +  " header3: " + df['header3'].astype(str)

# %%
df
# Out:
#                                                  title header1  \
# 0    UNITED STATES SECURITIES AND EXCHANGE COMMISSI...
# 1    UNITED STATES SECURITIES AND EXCHANGE COMMISSI...
# 2    MICROSOFT CORPORATION FORM 10-Q For the Quarte...
# 3    PART I. FINANCIAL INFORMATION ITEM 1. FINANCIA...
# 4                      COMPREHENSIVE INCOME STATEMENTS
# ..                                                 ...     ...
# 126  ITEM 2. UNREGISTERED SALES OF EQUITY SECURITIE...
# 127                                   ITEM 6. EXHIBITS
# 128                                          SIGNATURE
# 129                                      CERTIFICATION
# 130  CERTIFICATION PURSUANT TO SECTION 906 OF THE S...
#
#                    header2 header3  \
# 0
# 1    MICROSOFT CORPORATION
# 2
# 3
# 4
# ..                     ...     ...
# 126
# 127
# 128
# 129
# 130
#
#                                                content  token_length  \
# 0    FORM 10-Q\n:selected:\nQUARTERLY REPORT PURSUA...            99
# 1    WASHINGTON (STATE OF INCORPORATION)  \n91-1144...           597
# 2    | PART I. FINANCIAL INFORMATION ||| Page |\n||...           345
# 3    | (In millions, except per share amounts) (Una...           602
# 4    | (In millions) (Unaudited) | Three Months End...           231
# ..                                                 ...           ...
# 126  Following are our monthly share repurchases fo...           470
# 127  15.1 Letter regarding unaudited interim financ...           274
# 128  Pursuant to the requirements of the Securities...           311
# 129  I, Satya Nadella, certify that:  \n1\. I have ...          1256
# 130  In connection with the Quarterly Report of Mic...           473
#
#                                              full_text  \
# 0     title: UNITED STATES SECURITIES AND EXCHANGE ...
# 1     title: UNITED STATES SECURITIES AND EXCHANGE ...
# 2     title: MICROSOFT CORPORATION FORM 10-Q For th...
# 3     title: PART I. FINANCIAL INFORMATION ITEM 1. ...
# 4     title: COMPREHENSIVE INCOME STATEMENTS header...
# ..                                                 ...
# 126   title: ITEM 2. UNREGISTERED SALES OF EQUITY S...
# 127   title: ITEM 6. EXHIBITS header1:  header2:  h...
# 128   title: SIGNATURE header1:  header2:  header3:...
# 129   title: CERTIFICATION header1:  header2:  head...
# 130   title: CERTIFICATION PURSUANT TO SECTION 906 ...
#
#                                             full_title
# 0     title: UNITED STATES SECURITIES AND EXCHANGE ...
# 1     title: UNITED STATES SECURITIES AND EXCHANGE ...
# 2     title: MICROSOFT CORPORATION FORM 10-Q For th...
# 3     title: PART I. FINANCIAL INFORMATION ITEM 1. ...
# 4     title: COMPREHENSIVE INCOME STATEMENTS header...
# ..                                                 ...
# 126   title: ITEM 2. UNREGISTERED SALES OF EQUITY S...
# 127   title: ITEM 6. EXHIBITS header1:  header2:  h...
# 128     title: SIGNATURE header1:  header2:  header3:
# 129   title: CERTIFICATION header1:  header2:  head...
# 130   title: CERTIFICATION PURSUANT TO SECTION 906 ...
#
# [131 rows x 8 columns]

# %%
import openai
from typing import Any, Optional, Union
from tenacity import (
    retry,
    retry_if_exception_type,
    stop_after_attempt,
    wait_random_exponential,
)

load_dotenv()  

openai.api_type = "azure"
openai.api_base = os.getenv("AZURE_OPENAI_ENDPOINT")  
openai.api_version = "2024-05-01-preview"
openai.api_key = os.getenv("AZURE_OPENAI_API_KEY")  

deployment_name_embedding = "text-embedding-ada-002"

# %%
def before_retry_sleep(retry_state):
    print("Rate limited on the OpenAI embeddings API, sleeping before retrying...")

@retry(
    retry=retry_if_exception_type(openai.error.RateLimitError),
    wait=wait_random_exponential(min=15, max=60),
    stop=stop_after_attempt(15),
    before_sleep=before_retry_sleep,
)
def compute_embedding(text):
    #refresh_openai_token()
    #embedding_args = {"deployment_id": deployment_name_embedding} if args.openaihost != "openai" else {}
    return openai.Embedding.create(engine="text-embedding-3-small" , input=text)["data"][0]["embedding"]

# %%
df['full_title_vector'] = df['full_title'].apply(compute_embedding) 
df['content_vector'] = df['content'].apply(compute_embedding)

# %%
df[['title','header1','header2','header3','content','full_title_vector','content_vector']]
# Out:
#                                                  title header1  \
# 0    UNITED STATES SECURITIES AND EXCHANGE COMMISSI...
# 1    UNITED STATES SECURITIES AND EXCHANGE COMMISSI...
# 2    MICROSOFT CORPORATION FORM 10-Q For the Quarte...
# 3    PART I. FINANCIAL INFORMATION ITEM 1. FINANCIA...
# 4                      COMPREHENSIVE INCOME STATEMENTS
# ..                                                 ...     ...
# 126  ITEM 2. UNREGISTERED SALES OF EQUITY SECURITIE...
# 127                                   ITEM 6. EXHIBITS
# 128                                          SIGNATURE
# 129                                      CERTIFICATION
# 130  CERTIFICATION PURSUANT TO SECTION 906 OF THE S...
#
#                    header2 header3  \
# 0
# 1    MICROSOFT CORPORATION
# 2
# 3
# 4
# ..                     ...     ...
# 126
# 127
# 128
# 129
# 130
#
#                                                content  \
# 0    FORM 10-Q\n:selected:\nQUARTERLY REPORT PURSUA...
# 1    WASHINGTON (STATE OF INCORPORATION)  \n91-1144...
# 2    | PART I. FINANCIAL INFORMATION ||| Page |\n||...
# 3    | (In millions, except per share amounts) (Una...
# 4    | (In millions) (Unaudited) | Three Months End...
# ..                                                 ...
# 126  Following are our monthly share repurchases fo...
# 127  15.1 Letter regarding unaudited interim financ...
# 128  Pursuant to the requirements of the Securities...
# 129  I, Satya Nadella, certify that:  \n1\. I have ...
# 130  In connection with the Quarterly Report of Mic...
#
#                                      full_title_vector  \
# 0    [0.03364112973213196, 0.003108411328867078, 0....
# 1    [0.024496957659721375, -0.027848653495311737, ...
# 2    [0.05188297480344772, 0.014284387230873108, 0....
# 3    [-0.010826809331774712, -0.0069723669439554214...
# 4    [0.015895847231149673, 0.012530338950455189, 0...
# ..                                                 ...
# 126  [0.010583214461803436, 0.057578783482313156, 0...
# 127  [-0.018644539639353752, 0.031691934913396835, ...
# 128  [0.020313549786806107, 0.020454615354537964, 0...
# 129  [0.009701263159513474, 0.0226792823523283, 0.0...
# 130  [0.031683579087257385, 0.035888269543647766, 0...
#
#                                         content_vector
# 0    [0.05341602489352226, 0.0077919247560203075, 0...
# 1    [0.030771823599934578, -0.02253672480583191, 0...
# 2    [0.021289236843585968, 0.028044601902365685, 0...
# 3    [0.0006828737678006291, 0.003162274369969964, ...
# 4    [0.003113292623311281, 0.00854665320366621, 0....
# ..                                                 ...
# 126  [0.02236097864806652, 0.009578189812600613, 0....
# 127  [0.005142883397638798, 0.03827199339866638, 0....
# 128  [0.05372314900159836, 0.009199251420795918, 0....
# 129  [0.02512427605688572, 0.00577161880210042, 0.0...
# 130  [0.038419775664806366, -0.00494435615837574, 0...
#
# [131 rows x 7 columns]

# %%
def get_keywords_and_phrases(content):
    query = "can you extract a the key-value pair of the following text? text:" + content#table_html
    messages = [{"role":"system","content":"You are a bot that helps with extracting key-value pairs from text provided. Please provide the output in a json structure"}, 
               {"role":"user","content":query}]

    response = openai.ChatCompletion.create(engine="gpt4o",  
                                        messages = messages, 
                                        temperature=0.2,  
                                        max_tokens=1000,  top_p=0.5,  
                                        frequency_penalty=0,  
                                        presence_penalty=0,  
                                        stop=None)
    raw_extract = response.choices[0].message.content
    print(raw_extract)
    return raw_extract

# %%
text = get_keywords_and_phrases(df['content'][3])
# Out:
# ```json
# {
#   "Three Months Ended": {
#     "March 31, 2023": {
#       "Revenue": {
#         "Product": 15588,
#         "Service and other": 37269,
#         "Total revenue": 52857
#       },
#       "Cost of revenue": {
#         "Product": 3941,
#         "Service and other": 12187,
#         "Total cost of revenue": 16128
#       },
#       "Gross margin": 36729,
#       "Research and development": 6984,
#       "Sales and marketing": 5750,
#       "General and administrative": 1643,
#       "Operating income": 22352,
#       "Other income (expense), net": 321,
#       "Income before income taxes": 22673,
#       "Provision for income taxes": 4374,
#       "Net income": 18299,
#       "Earnings per share": {
#         "Basic": 2.46,
#         "Diluted": 2.45
#       },
#       "Weighted average shares outstanding": {
#         "Basic": 7441,
#         "Diluted": 7464
#       }
#     },
#     "March 31, 2022": {
#       "Revenue": {
#         "Product": 17366,
#         "Service and other": 31994,
#         "Total revenue": 49360
#       },
#       "Cost of revenue": {
#         "Product": 4584,
#         "Service and other": 11031,
#         "Total cost of revenue": 15615
#       },
#       "Gross margin": 33745,
#       "Research and development": 6306,
#       "Sales and marketing": 5595,
#       "General and administrative": 1480,
#       "Operating income": 20364,
#       "Other income (expense), net": -174,
#       "Income before income taxes": 20190,
#       "Provision for income taxes": 3462,
#       "Net income": 16728,
#       "Earnings per share": {
#         "Basic": 2.23,
#         "Diluted": 2.22
#       },
#       "Weighted average shares outstanding": {
#         "Basic": 7493,
#         "Diluted": 7534
#       }
#     }
#   },
#   "Nine Months Ended": {
#     "March 31, 2023": {
#       "Revenue": {
#         "Product": 47846,
#         "Service and other": 107880,
#         "Total revenue": 155726
#       },
#       "Cost of revenue": {
#         "Product": 13933,
#         "Service and other": 35135,
#         "Total cost of revenue": 49068
#       },
#       "Gross margin": 106658,
#       "Research and development": 20456,
#       "Sales and marketing": 16555,
#       "General and administrative": 5378,
#       "Operating income": 64269,
#       "Other income (expense), net": 315,
#       "Income before income taxes": 64584,
#       "Provision for income taxes": 12304,
#       "Net income": 52280,
#       "Earnings per share": {
#         "Basic": 7.02,
#         "Diluted": 6.99
#       },
#       "Weighted average shares outstanding": {
#         "Basic": 7450,
#         "Diluted": 7474
#       }
#     },
#     "March 31, 2022": {
#       "Revenue": {
#         "Product": 54776,
#         "Service and other": 91629,
#         "Total revenue": 146405
#       },
#       "Cost of revenue": {
#         "Product": 14707,
#         "Service and other": 31514,
#         "Total cost of revenue": 46221
#       },
#       "Gross margin": 100184,
#       "Research and development": 17663,
#       "Sales and marketing": 15521,
#       "General and administrative": 4151,
#       "Operating income": 62849,
#       "Other income (expense), net": 380,
#       "Income before income taxes": 63229,
#       "Provision for income taxes": 7231,
#       "Net income": 55998,
#       "Earnings per share": {
#         "Basic": 7.46,
#         "Diluted": 7.41
#       },
#       "Weighted average shares outstanding": {
#         "Basic": 7504,
#         "Diluted": 7552
#       }
#     }
#   }
# }
# ```

# %%
def answer_questions(text):
    query = "what was microsoft revenue for the 9 months that ended in march 2023?: text" + text#table_html
    messages = [{"role":"system","content":"You are a bot that helps with answering questions"}, 
               {"role":"user","content":query}]

    response = openai.ChatCompletion.create(engine="gpt4o",  
                                        messages = messages, 
                                        temperature=0.2,  
                                        max_tokens=1000,  top_p=0.5,  
                                        frequency_penalty=0,  
                                        presence_penalty=0,  
                                        stop=None)
    raw_extract = response.choices[0].message.content
    print(raw_extract)
    key_phrases = raw_extract

# %%
answer_questions(text)
# Out:
# For the nine months that ended on March 31, 2023, Microsoft's total revenue was $155,726 million. This revenue is broken down into:
#
# - Product revenue: $47,846 million
# - Service and other revenue: $107,880 million
